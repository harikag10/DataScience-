# %% [markdown]
#  Introduction to Data Science for Sports
#
# <br />
# <center>
#     <img src="ipynb.images/f1races.png" width=800 />
# </center>
#
# Question 1.1 (20 points) There are a number of F1 races coming up:
# - Singapore GP: Date: Sun, Sep 22, 8:10 AM
# - Russian GP: Date: Sun, Sep 29, 7:10 AM
# - Japanese GP: Date: Sun, Oct 13, 1:10 AM
# - Mexican GP Date: Sun, Oct 13, 1:10 AM
#
# The Singaporean Grand Prix this weekend and the Russian Grand Prix the weekend after, as you can see [here](https://www.formula1.com/en/racing/2019.html).
#
# The 2019 driver standings are given [here](https://www.formula1.com/en/results.html/2019/drivers.html). Given these standings (please do not use team standings given onthe same Web site, use driver standings), what is the Probability Distribution for each F1 driver to win the Singaporean Grand Prix? What is the Probability Distribution for each F1 driver to win *both* the Singaporean and Russian Grand Prix? What is the probability for Mercedes to win both races? What is the probability for Mercedes to win at least one race? Note that Mercedes, and each other racing team, has two drivers per race.
#
# Question 1.2 (30 points) If Mercedes wins the first race, what is the probability that Mercedes wins the next one? If Mercedes wins at least one of these two races, what is the probability Mercedes wins both races? How about Ferrari, Red Bull, and Renault?
#
# Question 1.3 (50 points) Mercedes wins one of these two races on a **rainy** day. What is the probability Mercedes wins both races, assuming races can be held on either rainy, sunny, cloudy, snowy or foggy days? Assume that rain, sun, clouds, snow, and fog are the *only possible weather conditions* on race tracks.
#
# You need to provide *proof* for your answers. `I think it's one in a million because Mercedes sucks and I like Ferrari a lot more` is not a good answer. Leverage the counting framework in this workbook!

# %% [markdown]
# ## Solutions

# %%
class ProbDist(dict):
    """A Probability Distribution; an {outcome: probability} mapping."""
    def __init__(self, mapping=(), **kwargs):
        self.update(mapping, **kwargs)
        # Make probabilities sum to 1.0; assert no negative probabilities
        total = sum(self.values())
        for outcome in self:
            self[outcome] = self[outcome] / total
            assert self[outcome] >= 0

# %%
def p(event, space): 
    """The probability of an event, given a sample space of outcomes. 
    event: a collection of outcomes, or a predicate that is true of outcomes in the event. 
    space: a set of outcomes or a probability distribution of {outcome: frequency} pairs."""
    
    # if event is a predicate it, "unroll" it as a collection 
    if is_predicate(event):
        event = such_that(event, space)
        
    # if space is not an equiprobably collection (a simple set), 
    # but a probability distribution instead (a dictionary set),
    # then add (union) the probabilities for all favorable outcomes
    if isinstance(space, ProbDist):
        return sum(space[o] for o in space if o in event)
    
    # simplest case: what we played with in our previous lesson
    else:
        return Fraction(len(event & space), len(space))

is_predicate = callable

# Here we either return a simple collection in the case of equiprobable outcomes, or a dictionary collection in the
# case of non-equiprobably outcomes
def such_that(predicate, space): 
    """The outcomes in the sample pace for which the predicate is true.
    If space is a set, return a subset {outcome,...} with outcomes where predicate(element) is true;
    if space is a ProbDist, return a ProbDist {outcome: frequency,...} with outcomes where predicate(element) is true."""
    if isinstance(space, ProbDist):
        return ProbDist({o:space[o] for o in space if predicate(o)})
    else:
        return {o for o in space if predicate(o)}

# %% [markdown]
# Please find the solutions to the following questions below
# ## Q1.1
# ## a) Probability Distribution for each F1 driver to win the Singaporean Grand Prix

# %%
SGP = ProbDist(LH = 284,VB=221,MV = 185,CL=182,SV=169,PG=65,
    CS=58,DR=34,AA=34,DK=33,NH=31,KR=31,SP=27,LN=25,
    LS=19,KM=18,RG=8,AG=3,RK=1,GR=0)
    
SGP
# Out:
# {'AA': 0.023809523809523808,
#  'AG': 0.0021008403361344537,
#  'CL': 0.12745098039215685,
#  'CS': 0.04061624649859944,
#  'DK': 0.023109243697478993,
#  'DR': 0.023809523809523808,
#  'GR': 0.0,
#  'KM': 0.012605042016806723,
#  'KR': 0.021708683473389355,
#  'LH': 0.19887955182072828,
#  'LN': 0.01750700280112045,
#  'LS': 0.01330532212885154,
#  'MV': 0.12955182072829133,
#  'NH': 0.021708683473389355,
#  'PG': 0.04551820728291316,
#  'RG': 0.0056022408963585435,
#  'RK': 0.0007002801120448179,
#  'SP': 0.018907563025210083,
#  'SV': 0.11834733893557423,
#  'VB': 0.15476190476190477}

# %% [markdown]
# ## b) Probability distribution for each F1 racer winning both Singapore and Russian GPs.

# %%
 # For Russian GP - RGP
#Taking the driver standing values post the Singapore GP

RGP = ProbDist(LH = 296,VB=231,MV = 200,CL=200,SV=194,PG=69,
    CS=58,DR=34,AA=42,DK=33,NH=33,KR=31,SP=27,LN=31,
    LS=19,KM=18,RG=8,AG=4,RK=1,GR=0)

# %%
# Obtaining the joint probability space for all driver combinations in Russian and Singapore GPs
def joint(A, B, sep=''):
    """The joint distribution of two independent probability distributions. 
    Result is all entries of the form {a+sep+b: P(a)*P(b)}"""
    return ProbDist({a + sep + b: A[a] * B[b]
                    for a in A
                     for b in B
                    })

SRGP = joint(SGP, RGP, ' ')
# SRGP - Singapore and Russian Joint probability space 
SRGP
# Out:
# {'AA AA': 0.0006540222367560493,
#  'AA AG': 6.22878320720047e-05,
#  'AA CL': 0.003114391603600235,
#  'AA CS': 0.0009031735650440681,
#  'AA DK': 0.0005138746145940388,
#  'AA DR': 0.00052944657261204,
#  'AA GR': 0.0,
#  'AA KM': 0.0002802952443240212,
#  'AA KR': 0.0004827306985580365,
#  'AA LH': 0.004609299573328348,
#  'AA LN': 0.0004827306985580365,
#  'AA LS': 0.0002958672023420224,
#  'AA MV': 0.003114391603600235,
#  'AA NH': 0.0005138746145940388,
#  'AA PG': 0.0010744651032420813,
#  'AA RG': 0.0001245756641440094,
#  'AA RK': 1.5571958018001176e-05,
#  'AA SP': 0.0004204428664860317,
#  'AA SV': 0.003020959855492228,
#  'AA VB': 0.0035971223021582714,
#  'AG AA': 5.770784441965141e-05,
#  'AG AG': 5.495985182823945e-06,
#  'AG CL': 0.0002747992591411972,
#  'AG CS': 7.969178515094718e-05,
#  'AG DK': 4.534187775829754e-05,
#  'AG DR': 4.671587405400353e-05,
#  'AG GR': 0.0,
#  'AG KM': 2.4731933322707752e-05,
#  'AG KR': 4.259388516688557e-05,
#  'AG LH': 0.0004067029035289719,
#  'AG LN': 4.259388516688557e-05,
#  'AG LS': 2.6105929618413737e-05,
#  'AG MV': 0.0002747992591411972,
#  'AG NH': 4.534187775829754e-05,
#  'AG PG': 9.480574440371304e-05,
#  'AG RG': 1.099197036564789e-05,
#  'AG RK': 1.3739962957059862e-06,
#  'AG SP': 3.709789998406163e-05,
#  'AG SV': 0.00026655528136696133,
#  'AG VB': 0.00031739314430808275,
#  'CL AA': 0.003500942561458852,
#  'CL AG': 0.0003334231010913193,
#  'CL CL': 0.016671155054565966,
#  'CL CS': 0.00483463496582413,
#  'CL DK': 0.002750740584003384,
#  'CL DR': 0.002834096359276214,
#  'CL GR': 0.0,
#  'CL KM': 0.0015004039549109368,
#  'CL KR': 0.0025840290334577247,
#  'CL LH': 0.02467330948075763,
#  'CL LN': 0.0025840290334577247,
#  'CL LS': 0.0015837597301837667,
#  'CL MV': 0.016671155054565966,
#  'CL NH': 0.002750740584003384,
#  'CL PG': 0.005751548493825258,
#  'CL RG': 0.0006668462021826386,
#  'CL RK': 8.335577527282982e-05,
#  'CL SP': 0.002250605932366405,
#  'CL SV': 0.016171020402928987,
#  'CL VB': 0.01925518408802369,
#  'CS AA': 0.0011156849921132607,
#  'CS AG': 0.00010625571353459628,
#  'CS CL': 0.005312785676729813,
#  'CS CS': 0.001540707846251646,
#  'CS DK': 0.0008766096366604192,
#  'CS DR': 0.0009031735650440682,
#  'CS GR': 0.0,
#  'CS KM': 0.0004781507109056832,
#  'CS KR': 0.0008234817798931212,
#  'CS LH': 0.007862922801560123,
#  'CS LN': 0.0008234817798931212,
#  'CS LS': 0.0005047146392893323,
#  'CS MV': 0.005312785676729813,
#  'CS NH': 0.0008766096366604192,
#  'CS PG': 0.0018329110584717856,
#  'CS RG': 0.00021251142706919256,
#  'CS RK': 2.656392838364907e-05,
#  'CS SP': 0.0007172260663585247,
#  'CS SV': 0.005153402106427919,
#  'CS VB': 0.006136267456622935,
#  'DK AA': 0.0006347862886161656,
#  'DK AG': 6.04558370110634e-05,
#  'DK CL': 0.00302279185055317,
#  'DK CS': 0.0008766096366604191,
#  'DK DK': 0.000498760655341273,
#  'DK DR': 0.0005138746145940388,
#  'DK GR': 0.0,
#  'DK KM': 0.00027205126654978527,
#  'DK KR': 0.0004685327368357413,
#  'DK LH': 0.004473731938818691,
#  'DK LN': 0.0004685327368357413,
#  'DK LS': 0.0002871652258025511,
#  'DK MV': 0.00302279185055317,
#  'DK NH': 0.000498760655341273,
#  'DK PG': 0.0010428631884408437,
#  'DK RG': 0.0001209116740221268,
#  'DK RK': 1.511395925276585e-05,
#  'DK SP': 0.00040807689982467793,
#  'DK SV': 0.0029321080950365746,
#  'DK VB': 0.003491324587388911,
#  'DR AA': 0.0006540222367560493,
#  'DR AG': 6.22878320720047e-05,
#  'DR CL': 0.003114391603600235,
#  'DR CS': 0.0009031735650440681,
#  'DR DK': 0.0005138746145940388,
#  'DR DR': 0.00052944657261204,
#  'DR GR': 0.0,
#  'DR KM': 0.0002802952443240212,
#  'DR KR': 0.0004827306985580365,
#  'DR LH': 0.004609299573328348,
#  'DR LN': 0.0004827306985580365,
#  'DR LS': 0.0002958672023420224,
#  'DR MV': 0.003114391603600235,
#  'DR NH': 0.0005138746145940388,
#  'DR PG': 0.0010744651032420813,
#  'DR RG': 0.0001245756641440094,
#  'DR RK': 1.5571958018001176e-05,
#  'DR SP': 0.0004204428664860317,
#  'DR SV': 0.003020959855492228,
#  'DR VB': 0.0035971223021582714,
#  'GR AA': 0.0,
#  'GR AG': 0.0,
#  'GR CL': 0.0,
#  'GR CS': 0.0,
#  'GR DK': 0.0,
#  'GR DR': 0.0,
#  'GR GR': 0.0,
#  'GR KM': 0.0,
#  'GR KR': 0.0,
#  'GR LH': 0.0,
#  'GR LN': 0.0,
#  'GR LS': 0.0,
#  'GR MV': 0.0,
#  'GR NH': 0.0,
#  'GR PG': 0.0,
#  'GR RG': 0.0,
#  'GR RK': 0.0,
#  'GR SP': 0.0,
#  'GR SV': 0.0,
#  'GR VB': 0.0,
#  'KM AA': 0.00034624706651790847,
#  'KM AG': 3.2975911096943674e-05,
#  'KM CL': 0.0016487955548471836,
#  'KM CS': 0.00047815071090568317,
#  'KM DK': 0.00027205126654978527,
#  'KM DR': 0.0002802952443240212,
#  'KM GR': 0.0,
#  'KM KM': 0.0001483915999362465,
#  'KM KR': 0.00025556331100131345,
#  'KM LH': 0.0024402174211738317,
#  'KM LN': 0.00025556331100131345,
#  'KM LS': 0.00015663557771048242,
#  'KM MV': 0.0016487955548471836,
#  'KM NH': 0.00027205126654978527,
#  'KM PG': 0.0005688344664222783,
#  'KM RG': 6.595182219388735e-05,
#  'KM RK': 8.243977774235918e-06,
#  'KM SP': 0.00022258739990436974,
#  'KM SV': 0.001599331688201768,
#  'KM VB': 0.001904358865848497,
#  'KR AA': 0.000596314392336398,
#  'KR AG': 5.6791846889180764e-05,
#  'KR CL': 0.002839592344459038,
#  'KR CS': 0.000823481779893121,
#  'KR DK': 0.00046853273683574126,
#  'KR DR': 0.00048273069855803646,
#  'KR GR': 0.0,
#  'KR KM': 0.0002555633110013134,
#  'KR KR': 0.0004401368133911509,
#  'KR LH': 0.004202596669799376,
#  'KR LN': 0.0004401368133911509,
#  'KR LS': 0.0002697612727236086,
#  'KR MV': 0.002839592344459038,
#  'KR NH': 0.00046853273683574126,
#  'KR PG': 0.0009796593588383682,
#  'KR RG': 0.00011358369377836153,
#  'KR RK': 1.4197961722295191e-05,
#  'KR SP': 0.0003833449665019701,
#  'KR SV': 0.0027544045741252667,
#  'KR VB': 0.003279729157850189,
#  'LH AA': 0.005463009271727,
#  'LH AG': 0.0005202865973073335,
#  'LH CL': 0.02601432986536667,
#  'LH CS': 0.007544155660956333,
#  'LH DK': 0.0042923644277855005,
#  'LH DR': 0.004422436077112334,
#  'LH GR': 0.0,
#  'LH KM': 0.0023412896878830004,
#  'LH KR': 0.0040322211291318345,
#  'LH LH': 0.038501208200742675,
#  'LH LN': 0.0040322211291318345,
#  'LH LS': 0.0024713613372098335,
#  'LH MV': 0.02601432986536667,
#  'LH NH': 0.0042923644277855005,
#  'LH PG': 0.008974943803551502,
#  'LH RG': 0.001040573194614667,
#  'LH RK': 0.00013007164932683337,
#  'LH SP': 0.0035119345318245,
#  'LH SV': 0.02523389996940567,
#  'LH VB': 0.030046550994498503,
#  'LN AA': 0.00048089870349709516,
#  'LN AG': 4.579987652353287e-05,
#  'LN CL': 0.0022899938261766437,
#  'LN CS': 0.0006640982095912265,
#  'LN DK': 0.00037784898131914624,
#  'LN DR': 0.00038929895045002944,
#  'LN GR': 0.0,
#  'LN KM': 0.00020609944435589795,
#  'LN KR': 0.0003549490430573798,
#  'LN LH': 0.003389190862741433,
#  'LN LN': 0.0003549490430573798,
#  'LN LS': 0.00021754941348678112,
#  'LN MV': 0.0022899938261766437,
#  'LN NH': 0.00037784898131914624,
#  'LN PG': 0.0007900478700309421,
#  'LN RG': 9.159975304706575e-05,
#  'LN RK': 1.1449969130883218e-05,
#  'LN SP': 0.00030914916653384687,
#  'LN SV': 0.0022212940113913444,
#  'LN VB': 0.0026449428692340233,
#  'LS AA': 0.0003654830146577923,
#  'LS AG': 3.480790615788499e-05,
#  'LS CL': 0.001740395307894249,
#  'LS CS': 0.0005047146392893322,
#  'LS DK': 0.0002871652258025511,
#  'LS DR': 0.0002958672023420224,
#  'LS GR': 0.0,
#  'LS KM': 0.00015663557771048242,
#  'LS KR': 0.00026976127272360865,
#  'LS LH': 0.0025757850556834883,
#  'LS LN': 0.00026976127272360865,
#  'LS LS': 0.00016533755424995365,
#  'LS MV': 0.001740395307894249,
#  'LS NH': 0.0002871652258025511,
#  'LS PG': 0.000600436381223516,
#  'LS RG': 6.961581231576998e-05,
#  'LS RK': 8.701976539471247e-06,
#  'LS SP': 0.00023495336656572361,
#  'LS SV': 0.0016881834486574218,
#  'LS VB': 0.002010156580617858,
#  'MV AA': 0.003558650405878504,
#  'MV AG': 0.0003389190862741433,
#  'MV CL': 0.016945954313707164,
#  'MV CS': 0.0049143267509750765,
#  'MV DK': 0.0027960824617616824,
#  'MV DR': 0.002880812233330218,
#  'MV GR': 0.0,
#  'MV KM': 0.0015251358882336448,
#  'MV KR': 0.0026266229186246107,
#  'MV LH': 0.025080012384286605,
#  'MV LN': 0.0026266229186246107,
#  'MV LS': 0.0016098656598021806,
#  'MV MV': 0.016945954313707164,
#  'MV NH': 0.0027960824617616824,
#  'MV PG': 0.005846354238228972,
#  'MV RG': 0.0006778381725482866,
#  'MV RK': 8.472977156853582e-05,
#  'MV SP': 0.002287703832350467,
#  'MV SV': 0.01643757568429595,
#  'MV VB': 0.019572577232331773,
#  'NH AA': 0.000596314392336398,
#  'NH AG': 5.6791846889180764e-05,
#  'NH CL': 0.002839592344459038,
#  'NH CS': 0.000823481779893121,
#  'NH DK': 0.00046853273683574126,
#  'NH DR': 0.00048273069855803646,
#  'NH GR': 0.0,
#  'NH KM': 0.0002555633110013134,
#  'NH KR': 0.0004401368133911509,
#  'NH LH': 0.004202596669799376,
#  'NH LN': 0.0004401368133911509,
#  'NH LS': 0.0002697612727236086,
#  'NH MV': 0.002839592344459038,
#  'NH NH': 0.00046853273683574126,
#  'NH PG': 0.0009796593588383682,
#  'NH RG': 0.00011358369377836153,
#  'NH RK': 1.4197961722295191e-05,
#  'NH SP': 0.0003833449665019701,
#  'NH SV': 0.0027544045741252667,
#  'NH VB': 0.003279729157850189,
#  'PG AA': 0.0012503366290924473,
#  'PG AG': 0.00011907967896118547,
#  'PG CL': 0.005953983948059273,
#  'PG CS': 0.001726655344937189,
#  'PG DK': 0.00098240735142978,
#  'PG DR': 0.0010121772711700766,
#  'PG GR': 0.0,
#  'PG KM': 0.0005358585553253346,
#  'PG KR': 0.0009228675119491874,
#  'PG LH': 0.008811896243127724,
#  'PG LN': 0.0009228675119491874,
#  'PG LS': 0.000565628475065631,
#  'PG MV': 0.005953983948059273,
#  'PG NH': 0.00098240735142978,
#  'PG PG': 0.0020541244620804495,
#  'PG RG': 0.00023815935792237094,
#  'PG RK': 2.9769919740296367e-05,
#  'PG SP': 0.0008037878329880019,
#  'PG SV': 0.005775364429617495,
#  'PG VB': 0.00687685146000846,
#  'RG AA': 0.00015388758511907042,
#  'RG AG': 1.465596048753052e-05,
#  'RG CL': 0.000732798024376526,
#  'RG CS': 0.00021251142706919254,
#  'RG DK': 0.00012091167402212679,
#  'RG DR': 0.0001245756641440094,
#  'RG GR': 0.0,
#  'RG KM': 6.595182219388733e-05,
#  'RG KR': 0.00011358369377836153,
#  'RG LH': 0.0010845410760772585,
#  'RG LN': 0.00011358369377836153,
#  'RG LS': 6.961581231576996e-05,
#  'RG MV': 0.000732798024376526,
#  'RG NH': 0.00012091167402212679,
#  'RG PG': 0.00025281531840990146,
#  'RG RG': 2.931192097506104e-05,
#  'RG RK': 3.66399012188263e-06,
#  'RG SP': 9.892773329083101e-05,
#  'RG SV': 0.0007108140836452302,
#  'RG VB': 0.0008463817181548876,
#  'RK AA': 1.9235948139883803e-05,
#  'RK AG': 1.831995060941315e-06,
#  'RK CL': 9.159975304706575e-05,
#  'RK CS': 2.6563928383649067e-05,
#  'RK DK': 1.5113959252765849e-05,
#  'RK DR': 1.5571958018001176e-05,
#  'RK GR': 0.0,
#  'RK KM': 8.243977774235917e-06,
#  'RK KR': 1.4197961722295191e-05,
#  'RK LH': 0.0001355676345096573,
#  'RK LN': 1.4197961722295191e-05,
#  'RK LS': 8.701976539471246e-06,
#  'RK MV': 9.159975304706575e-05,
#  'RK NH': 1.5113959252765849e-05,
#  'RK PG': 3.160191480123768e-05,
#  'RK RG': 3.66399012188263e-06,
#  'RK RK': 4.5799876523532875e-07,
#  'RK SP': 1.2365966661353876e-05,
#  'RK SV': 8.885176045565378e-05,
#  'RK VB': 0.00010579771476936094,
#  'SP AA': 0.0005193705997768627,
#  'SP AG': 4.9463866645415504e-05,
#  'SP CL': 0.0024731933322707745,
#  'SP CS': 0.0007172260663585246,
#  'SP DK': 0.0004080768998246779,
#  'SP DR': 0.0004204428664860318,
#  'SP GR': 0.0,
#  'SP KM': 0.00022258739990436974,
#  'SP KR': 0.0003833449665019702,
#  'SP LH': 0.0036603261317607466,
#  'SP LN': 0.0003833449665019702,
#  'SP LS': 0.00023495336656572361,
#  'SP MV': 0.0024731933322707745,
#  'SP NH': 0.0004080768998246779,
#  'SP PG': 0.0008532516996334175,
#  'SP RG': 9.892773329083101e-05,
#  'SP RK': 1.2365966661353876e-05,
#  'SP SP': 0.00033388109985655457,
#  'SP SV': 0.002398997532302652,
#  'SP VB': 0.0028565382987727453,
#  'SV AA': 0.003250875235640363,
#  'SV AG': 0.0003096071652990822,
#  'SV CL': 0.01548035826495411,
#  'SV CS': 0.004489303896836692,
#  'SV DK': 0.002554259113717428,
#  'SV DR': 0.002631660905042199,
#  'SV GR': 0.0,
#  'SV KM': 0.0013932322438458698,
#  'SV KR': 0.0023994555310678876,
#  'SV LH': 0.022910930232132084,
#  'SV LN': 0.0023994555310678876,
#  'SV LS': 0.0014706340351706404,
#  'SV MV': 0.01548035826495411,
#  'SV NH': 0.002554259113717428,
#  'SV PG': 0.005340723601409168,
#  'SV RG': 0.0006192143305981644,
#  'SV RK': 7.740179132477055e-05,
#  'SV SP': 0.002089848365768805,
#  'SV SV': 0.015015947517005487,
#  'SV VB': 0.017879813796022,
#  'VB AA': 0.004251144538914321,
#  'VB AG': 0.00040487090846803067,
#  'VB CL': 0.020243545423401527,
#  'VB CS': 0.005870628172786443,
#  'VB DK': 0.003340184994861253,
#  'VB DR': 0.0034414027219782603,
#  'VB GR': 0.0,
#  'VB KM': 0.0018219190881061376,
#  'VB KR': 0.0031377495406272374,
#  'VB LH': 0.029960447226634265,
#  'VB LN': 0.0031377495406272374,
#  'VB LS': 0.0019231368152231453,
#  'VB MV': 0.020243545423401527,
#  'VB NH': 0.003340184994861253,
#  'VB PG': 0.0069840231710735275,
#  'VB RG': 0.0008097418169360613,
#  'VB RK': 0.00010121772711700767,
#  'VB SP': 0.0027328786321592063,
#  'VB SV': 0.019636239060699483,
#  'VB VB': 0.023381294964028767}

# %%
# Here is the probability distribution of each racer winning both races

# %%
# predicate defining the outcomes where both the drivers are same i.e same driver wins in both races.
def WinBothRaces(outcome): return outcome[0]+outcome[1]==outcome[3]+outcome[4] 
# now we return the collection of outcomes where the same driver wins both the races, from the joint probability space of Singapore and Russian (SRGP)
# which gives us our desired probabilty distribtuion of same racer winning both the races.
such_that(WinBothRaces,SRGP)
# Out:
# {'AA AA': 0.005554842398851687,
#  'AG AG': 4.667934788950998e-05,
#  'CL CL': 0.1415940219315136,
#  'CS CS': 0.013085777191692632,
#  'DK DK': 0.004236150820973031,
#  'DR DR': 0.004496777180022795,
#  'GR GR': 0.0,
#  'KM KM': 0.0012603423930167695,
#  'KR KR': 0.003738237776818258,
#  'LH LH': 0.32700439174864726,
#  'LN LN': 0.0030147078845308532,
#  'LS LS': 0.0014042703823427584,
#  'MV MV': 0.1439279893259891,
#  'NH NH': 0.003979414407580726,
#  'PG PG': 0.017446406273704355,
#  'RG RG': 0.0002489565220773866,
#  'RK RK': 3.889945657459165e-06,
#  'SP SP': 0.0028357703842877306,
#  'SV SV': 0.1275357583254562,
#  'VB VB': 0.19858561575894784}

# %% [markdown]
# ## c) Probability for Mercedes to win both races - is the probability that Lewis Hamilton or Valterri Bottas have to win both races

# %%
def BothMercedes(outcome): 
    return (('LH' in outcome and 'VB' in outcome) or 
            (outcome.startswith('LH') and outcome.endswith('LH')) or 
            (outcome.startswith('VB') and outcome.endswith('VB')))
such_that(BothMercedes,SRGP)
# here is the probability 
p(BothMercedes,SRGP)
# Out:
# 0.12188950138590421

# %% [markdown]
# ## d) Probability for Mercedes to win at least one race

# %%
def Mercedes(outcome): return 'LH' in outcome or 'VB' in outcome
such_that(Mercedes,SRGP)
#probability 
p(Mercedes,SRGP)
# Out:
# 0.5764216739671669

# %% [markdown]
# ## Q1.2
# ## a) If Mercedes wins the first race, what is the probability that Mercedes wins the next one?

# %%
def firstMer(outcome): return outcome.startswith('LH') or outcome.startswith('VB')
# firstMer -> Mercedes in the first race
such_that(firstMer,SRGP) 

def secondMer(outcome):return outcome.endswith('LH') or outcome.endswith('VB')
# secondMer - > Mercedes in the second race
such_that(secondMer,SRGP)


'''Here is the PROBABILITY of mercedes winning the secondrace given that first race is won by Mercedes''' 
p(secondMer,such_that(firstMer,SRGP))
# Out:
# 0.3446697187704381

# %% [markdown]
# ## b) If Mercedes wins at least one of these two races, what is the probability Mercedes wins both races?

# %%
# such_that(Mercedes,SRGP) returns the sample where Mercedes wins atleast one of the 2 races as we have obtained earlier, 
# so given that, we are calculating the event of Mercedes winning both using the predicate BothMercedes,
# which is also already implemented above"

p(BothMercedes,such_that(Mercedes,SRGP))
# Out:
# 0.21145891435173053

# %% [markdown]
# ## c) How about Ferrari, Red Bull, and Renault?
#
# Ans - Similarly implementing the same probability functions for the above 3
# 1- Ferrari it is the ProbDist outcomes for Charles Leclerc(CL) or Sebastien Vettel(SV)
#
# 2- Red Bull - Max Verstappen(MV) or Alexander Albon(AA)
#
# 3- Renault - Daniel Ricciardo(DR) or Nico Hulkenberg(NH)

# %% [markdown]
# ## c.1) Ferrari --

# %% [markdown]
# ## Probability of Ferrari winning the secondrace given that first race is won by Ferrari

# %%
'''Ferrari'''
def firstFerr(outcome): return outcome.startswith('CL') or outcome.startswith('SV')
# firstFerr -> Ferrari in the first race
such_that(firstFerr,SRGP) 

def secondFerr(outcome):return outcome.endswith('CL') or outcome.endswith('SV')
# secondFerr - > Ferrari in the second race
such_that(secondFerr,SRGP)


'''Here is the PROBABILITY of Ferrari winning the secondrace given that first race is won by Ferrari''' 
p(secondFerr,such_that(firstFerr,SRGP))
# Out:
# 0.25768476128188367

# %% [markdown]
# ## Probability of Ferrari winning both races given that it has won atleast one of the 2 races

# %%
# defining the predicate for ferrari to win both races
def BothFerrari(outcome): return outcome.startswith('CL') and outcome.endswith('CL') or outcome.startswith('SV') and outcome.endswith('SV')
such_that(BothFerrari,SRGP)

# predicate for ferrari to win atlease one race
def Ferrari(outcome): return 'CL' in outcome or 'SV' in outcome
such_that(Ferrari,SRGP)

'''Probability of Ferrari winning both races given that it has won atleast one of the 2 races '''
p(BothFerrari,such_that(Ferrari,SRGP))
# Out:
# 0.0719924829633607

# %% [markdown]
# ## c.2) RedBull --
#
# ## Probability of RedBull winning the secondrace given that first race is won by RedBull

# %%
'''RedBull'''
def firstRB(outcome): return outcome.startswith('MV') or outcome.startswith('AA')
#firstRB -> RedBull in the first race
such_that(firstRB,SRGP) 

def secondRB(outcome):return outcome.endswith('MV') or outcome.endswith('AA')
#secondRB - > RedBull in the second race
such_that(secondRB,SRGP)


'''Here is the probability of RedBull winning the secondrace given that first race is won by RedBull'''
p(secondRB,such_that(firstRB,SRGP))
# Out:
# 0.15827338129496407

# %% [markdown]
# ## Probability of RedBull winning both races given that it has won atleast one of the 2 races

# %%
# defining the predicate for RedBull to win both races"
def BothRB(outcome): return outcome.startswith('MV') and outcome.endswith('MV') or outcome.startswith('AA') and outcome.endswith('AA')
such_that(BothRB,SRGP)

# predicate for ferrari to win atlease one race"
def RedBull(outcome): return 'MV' in outcome or 'AA' in outcome
such_that(RedBull,SRGP)

'''Probability of RedBull winning both races given that it has won atleast one of the 2 races '''
p(BothRB,such_that(RedBull,SRGP))
# Out:
# 0.06124677055093085

# %% [markdown]
# ## c.3) Renault --
#
# ## Probability of Renault winning the secondrace given that first race is won by Renault

# %%
'''Renault'''
def firstRenault(outcome): return outcome.startswith('DR') or outcome.startswith('NH')
# firstRenault -> Renault in the first race
such_that(firstRenault,SRGP) 

def secondRenault(outcome):return outcome.endswith('DR') or outcome.endswith('NH')
# secondRenault - > Renault in the second race
such_that(secondRenault,SRGP)


'''here is the probability of Renault winning the secondrace given that first race is won by Renault'''
p(secondRenault,such_that(firstRenault,SRGP))
# Out:
# 0.043819489862655346

# %% [markdown]
# ## Probability of Renault winning both races given that it has won atleast one of the 2 races

# %%
# defining the predicate for renault to win both races
def BothRenault(outcome): return outcome.startswith('DR') and outcome.endswith('DR') or outcome.startswith('NH') and outcome.endswith('NH')
such_that(BothRenault,SRGP)

# predicate for renault to win atlease one race
def Renault(outcome): return 'DR' in outcome or 'NH' in outcome
such_that(Renault,SRGP)

'''Probability of Renault winning both races given that it has won atleast one of the 2 races'''
p(BothRenault,such_that(Renault,SRGP))
# Out:
# 0.011425964573741784

# %% [markdown]
# ## Q 1.3

# %% [markdown]
# Mercedes wins one of these two races on a rainy day. What is the probability Mercedes wins both races, assuming races can be held on either rainy, sunny, cloudy, snowy or foggy days? Assume that rain, sun, clouds, snow, and fog are the only possible weather conditions on race tracks.

# %%
# There are 5 weather conditions - rain, sun,clouds , snow and fog 
# Implementing the Probability distribution taking weather also as one of the criteria.

# %%
weather=ProbDist(rain=1,sun=1,clouds=1,snow=1,fog=1)
weather
# Out:
# {'clouds': 0.2, 'fog': 0.2, 'rain': 0.2, 'snow': 0.2, 'sun': 0.2}

# %%
# Taking the weather conditions into effect
def joint(A, B, C , D, sep=''):
        return ProbDist({a + sep + c + sep + b + sep + d  : A[a] * B[b] * C[c] * D[d]
                    for a in A
                     for b in B
                      for c in C
                       for d in D 
                    })

SRWC = joint(SGP, RGP, weather, weather, ' ')
''' SRWC - Joint probability space of Singapore and Russian races including the weather conditions '''
SRWC
# Out:
# {'NH sun SP clouds': 1.533379866007864e-05,
#  'KM fog AG snow': 1.3190364438777328e-06,
#  'PG clouds KM rain': 2.143434221301315e-05,
#  'SP fog KM sun': 8.903495996174692e-06,
#  'AA snow SP sun': 1.6817714659441087e-05,
#  'KM fog VB sun': 7.617435463393906e-05,
#  'GR clouds MV snow': 0.0,
#  'RK clouds MV rain': 3.6639901218825906e-06,
#  'AG clouds LH rain': 1.6268116141158703e-05,
#  'RK fog KM clouds': 3.297591109694331e-07,
#  'LS clouds GR fog': 0.0,
#  'RK snow GR clouds': 0.0,
#  'DK sun LN clouds': 1.874130947342945e-05,
#  'LH sun KM sun': 9.3651587515319e-05,
#  'LN fog AG snow': 1.8319950609412953e-06,
#  'RK clouds MV sun': 3.6639901218825906e-06,
#  'RK snow DR clouds': 6.228783207200403e-07,
#  'LN sun GR rain': 0.0,
#  'CS snow LS snow': 2.0188585571573077e-05,
#  'SP snow GR fog': 0.0,
#  'KM sun LH clouds': 9.760869684695219e-05,
#  'SV clouds LH rain': 0.0009164372092852736,
#  'RG rain LN snow': 4.5433477511344126e-06,
#  'RK fog VB clouds': 4.2319085907743915e-06,
#  'VB rain AG rain': 1.619483633872105e-05,
#  'DK snow RG snow': 4.8364669608850205e-06,
#  'KR fog SP clouds': 1.533379866007864e-05,
#  'MV snow GR clouds': 0.0,
#  'NH snow LH clouds': 0.00016810386679197323,
#  'DR rain LS fog': 1.1834688093680766e-05,
#  'MV clouds GR snow': 0.0,
#  'PG rain LS rain': 2.2625139002624997e-05,
#  'PG snow AG sun': 4.763187158447367e-06,
#  'RK rain MV fog': 3.6639901218825906e-06,
#  'KR snow RG rain': 4.5433477511344126e-06,
#  'SV rain LN snow': 9.597822124271446e-05,
#  'SV snow MV clouds': 0.0006192143305981577,
#  'KM snow LS rain': 6.265423108419229e-06,
#  'SV snow SV snow': 0.000600637900680213,
#  'LS clouds LH clouds': 0.00010303140222733843,
#  'PG fog VB clouds': 0.00027507405840033545,
#  'GR clouds AG rain': 0.0,
#  'SP clouds RK fog': 4.946386664541497e-07,
#  'KM sun CL fog': 6.595182219388663e-05,
#  'KR snow RK clouds': 5.679184688918016e-07,
#  'AG snow PG fog': 3.792229776148481e-06,
#  'SP clouds RK clouds': 4.946386664541497e-07,
#  'RK sun VB clouds': 4.2319085907743915e-06,
#  'AG fog AG clouds': 2.1983940731295544e-07,
#  'DK clouds DR rain': 2.055498458376133e-05,
#  'AA fog RG fog': 4.983026565760322e-06,
#  'CS rain DK sun': 3.506438546641639e-05,
#  'PG sun SV snow': 0.0002310145771846973,
#  'DR fog KM rain': 1.1211809772960727e-05,
#  'MV sun PG fog': 0.00023385416952915634,
#  'LN sun RG rain': 3.6639901218825906e-06,
#  'RG fog KM sun': 2.6380728877554647e-06,
#  'MV clouds NH snow': 0.00011184329847046608,
#  'AA sun VB fog': 0.0001438848920863293,
#  'KR sun LN snow': 1.7605472535645848e-05,
#  'RK clouds MV fog': 3.6639901218825906e-06,
#  'AA clouds DK fog': 2.055498458376133e-05,
#  'VB rain AA snow': 0.00017004578155657102,
#  'GR fog AA sun': 0.0,
#  'DR fog SV fog': 0.00012083839421968782,
#  'LH sun AG snow': 2.0811463892293114e-05,
#  'LH snow SP fog': 0.00014047738127297848,
#  'AG snow AG clouds': 2.1983940731295544e-07,
#  'LH fog DK fog': 0.00017169457711141816,
#  'LH fog AG snow': 2.0811463892293114e-05,
#  'GR clouds LN clouds': 0.0,
#  'MV snow GR fog': 0.0,
#  'KM rain LH fog': 9.760869684695219e-05,
#  'CL clouds SV snow': 0.0006468408161171525,
#  'DR clouds DK fog': 2.055498458376133e-05,
#  'CL fog AA clouds': 0.00014003770245835255,
#  'AA rain AG clouds': 2.491513282880161e-06,
#  'VB fog DK snow': 0.00013360739979444866,
#  'VB clouds LS fog': 7.692547260892499e-05,
#  'DR clouds KM rain': 1.1211809772960727e-05,
#  'SP snow LS sun': 9.398134662628844e-06,
#  'KR rain RK sun': 5.679184688918016e-07,
#  'AG rain MV fog': 1.0991970365647771e-05,
#  'LH fog KR rain': 0.00016128884516527166,
#  'RK fog DR fog': 6.228783207200403e-07,
#  'PG sun VB sun': 0.00027507405840033545,
#  'DK rain DR snow': 2.055498458376133e-05,
#  'GR rain DK rain': 0.0,
#  'GR fog VB clouds': 0.0,
#  'RK clouds NH sun': 6.045583701106275e-07,
#  'LN sun LN fog': 1.4197961722295037e-05,
#  'GR sun VB rain': 0.0,
#  'LS clouds KR sun': 1.079045090894423e-05,
#  'VB rain SP rain': 0.00010931514528636708,
#  'LH rain LS snow': 9.885445348839226e-05,
#  'CS fog GR clouds': 0.0,
#  'LN rain KM snow': 8.243977774235829e-06,
#  'CS rain VB rain': 0.0002454506982649148,
#  'CL fog NH sun': 0.00011002962336013417,
#  'GR sun NH fog': 0.0,
#  'RK clouds NH clouds': 6.045583701106275e-07,
#  'CS fog NH snow': 3.506438546641639e-05,
#  'LS fog LS fog': 6.613502169998075e-06,
#  'LN fog LH fog': 0.00013556763450965585,
#  'KR snow CL sun': 0.00011358369377836028,
#  'VB snow AG fog': 1.619483633872105e-05,
#  'SP fog CL rain': 9.892773329082991e-05,
#  'LN fog GR clouds': 0.0,
#  'KR sun AG fog': 2.2716738755672063e-06,
#  'CL sun KM clouds': 6.001615819643683e-05,
#  'GR snow SV fog': 0.0,
#  'MV fog LS rain': 6.439462639208652e-05,
#  'VB sun RK clouds': 4.0487090846802625e-06,
#  'KR snow DK clouds': 1.8741309473429446e-05,
#  'AA clouds CL sun': 0.00012457566414400805,
#  'GR rain LH fog': 0.0,
#  'KM rain PG fog': 2.2753378656890887e-05,
#  'PG clouds CS fog': 6.906621379748681e-05,
#  'SV clouds LS sun': 5.8825361406824986e-05,
#  'KR snow LH clouds': 0.00016810386679197323,
#  'RG clouds RK rain': 1.4655960487530363e-07,
#  'AA sun DK snow': 2.055498458376133e-05,
#  'SP fog MV fog': 9.892773329082991e-05,
#  'CS snow RG fog': 8.500457082767611e-06,
#  'LH snow PG clouds': 0.00035899775214205616,
#  'VB clouds DK snow': 0.00013360739979444866,
#  'LH fog NH snow': 0.00017169457711141816,
#  'DR rain AG clouds': 2.491513282880161e-06,
#  'NH snow AA sun': 2.385257569345566e-05,
#  'LN rain GR clouds': 0.0,
#  'VB fog SP rain': 0.00010931514528636708,
#  'KM clouds GR rain': 0.0,
#  'LS fog AA clouds': 1.4619320586311533e-05,
#  'SP clouds PG fog': 3.413006798533633e-05,
#  'LH sun PG rain': 0.00035899775214205616,
#  'LN rain CS rain': 2.6563928383648772e-05,
#  'KR snow PG fog': 3.918637435353431e-05,
#  'CS rain DK snow': 3.506438546641639e-05,
#  'MV sun CS snow': 0.00019657307003900096,
#  'CS clouds CL rain': 0.00021251142706919023,
#  'PG sun LN rain': 3.69147004779671e-05,
#  'LN fog RK rain': 4.579987652353238e-07,
#  'SP rain MV rain': 9.892773329082991e-05,
#  'GR rain PG rain': 0.0,
#  'SV snow AA sun': 0.00013003500942561312,
#  'LN sun CL clouds': 9.159975304706474e-05,
#  'RG fog KM fog': 2.6380728877554647e-06,
#  'VB fog LS clouds': 7.692547260892499e-05,
#  'AG snow NH sun': 1.8136751103318824e-06,
#  'KR clouds KM clouds': 1.0222532440052427e-05,
#  'LH fog DR sun': 0.00017689744308449143,
#  'CS fog VB snow': 0.0002454506982649148,
#  'MV snow SP snow': 9.150815329401769e-05,
#  'RK snow MV sun': 3.6639901218825906e-06,
#  'LS fog SP sun': 9.398134662628844e-06,
#  'NH fog LN fog': 1.7605472535645848e-05,
#  'DR fog SP sun': 1.6817714659441087e-05,
#  'LN rain KR sun': 1.4197961722295037e-05,
#  'KR fog GR fog': 0.0,
#  'LN sun SP fog': 1.2365966661353742e-05,
#  'LS sun MV sun': 6.961581231576922e-05,
#  'LN fog PG clouds': 3.160191480123734e-05,
#  'PG snow LS snow': 2.2625139002624997e-05,
#  'PG snow MV clouds': 0.00023815935792236833,
#  'AA snow LH sun': 0.00018437198293313193,
#  'MV snow DR sun': 0.00011523248933320747,
#  'MV sun SV fog': 0.0006575030273718309,
#  'AG snow CS clouds': 3.1876714060378533e-06,
#  'NH fog LH clouds': 0.00016810386679197323,
#  'RG rain NH snow': 4.83646696088502e-06,
#  'LS clouds KR clouds': 1.079045090894423e-05,
#  'RK snow LS rain': 3.480790615788461e-07,
#  'AG fog SV snow': 1.0662211254678338e-05,
#  'RG rain KR fog': 4.5433477511344126e-06,
#  'KR fog NH sun': 1.8741309473429446e-05,
#  'RG sun SP clouds': 3.957109331633198e-06,
#  'DR rain AG rain': 2.491513282880161e-06,
#  'AA snow MV sun': 0.00012457566414400805,
#  'LN rain VB fog': 0.00010579771476935979,
#  'MV fog CS rain': 0.00019657307003900096,
#  'AA rain NH sun': 2.055498458376133e-05,
#  'CL sun CL fog': 0.0006668462021826314,
#  'LN sun DK clouds': 1.5113959252765686e-05,
#  'LS fog PG clouds': 2.4017455248940376e-05,
#  'KR rain LH fog': 0.00016810386679197323,
#  'MV snow SV snow': 0.0006575030273718309,
#  'KM sun AA rain': 1.384988266071619e-05,
#  'AG snow LS clouds': 1.0442371847365382e-06,
#  'AG sun RG rain': 4.396788146259109e-07,
#  'LS rain DK snow': 1.1486609032101921e-05,
#  'RG fog AG rain': 5.862384195012145e-07,
#  'LS rain CL rain': 6.961581231576922e-05,
#  'RK clouds KM rain': 3.297591109694331e-07,
#  'VB fog LN clouds': 0.00012550998162508815,
#  'NH sun DK snow': 1.8741309473429446e-05,
#  'LS clouds AA fog': 1.4619320586311533e-05,
#  'VB fog GR fog': 0.0,
#  'DR fog CS fog': 3.6126942601762336e-05,
#  'SP snow NH fog': 1.6323075992986937e-05,
#  'PG sun CS rain': 6.906621379748681e-05,
#  'DK sun RK snow': 6.045583701106276e-07,
#  'RG fog CL sun': 2.9311920975060725e-05,
#  'LH rain GR fog': 0.0,
#  'LH snow VB clouds': 0.0012018620397799271,
#  'DK clouds RG snow': 4.8364669608850205e-06,
#  'LH fog LN snow': 0.00016128884516527166,
#  'MV fog SV rain': 0.0006575030273718309,
#  'NH fog AG clouds': 2.2716738755672063e-06,
#  'CS clouds KR fog': 3.293927119572449e-05,
#  'KM rain CL fog': 6.595182219388663e-05,
#  'KR clouds KR rain': 1.7605472535645848e-05,
#  'KR snow RK snow': 5.679184688918016e-07,
#  'SP rain LN sun': 1.5333798660078644e-05,
#  'LH sun DR rain': 0.00017689744308449143,
#  'SP sun SV sun': 9.595990129210503e-05,
#  'MV clouds GR fog': 0.0,
#  'PG sun RG snow': 9.526374316894734e-06,
#  'KM snow CS clouds': 1.912602843622712e-05,
#  'SV sun CL snow': 0.0006192143305981577,
#  'CS clouds RK rain': 1.0625571353459514e-06,
#  'KM fog RK sun': 3.297591109694332e-07,
#  'AA rain LH clouds': 0.00018437198293313193,
#  'KM rain PG clouds': 2.2753378656890887e-05,
#  'LH rain LS clouds': 9.885445348839226e-05,
#  'LN fog RK fog': 4.579987652353238e-07,
#  'LH clouds KM sun': 9.3651587515319e-05,
#  'AA sun AA clouds': 2.6160889470241693e-05,
#  'LS sun SP snow': 9.398134662628844e-06,
#  'NH clouds AG fog': 2.2716738755672063e-06,
#  'DK fog DR sun': 2.055498458376133e-05,
#  'LH clouds SV snow': 0.0010093559987762158,
#  'PG fog SP clouds': 3.215151331951972e-05,
#  'DK rain CL clouds': 0.00012091167402212549,
#  'MV clouds AG fog': 1.3556763450965585e-05,
#  'KR fog LN clouds': 1.7605472535645848e-05,
#  'SP fog VB rain': 0.00011426153195090858,
#  'RG snow VB rain': 3.385526872619513e-05,
#  'RK sun LH rain': 5.4227053803862345e-06,
#  'GR snow DK clouds': 0.0,
#  'KR fog PG snow': 3.918637435353431e-05,
#  'LS snow VB rain': 8.040626322471346e-05,
#  'VB clouds VB rain': 0.0009352517985611406,
#  'KM snow KM rain': 5.935663997449796e-06,
#  'KR sun MV sun': 0.00011358369377836028,
#  'SV fog LS rain': 5.8825361406824986e-05,
#  'GR snow CS clouds': 0.0,
#  'AA snow CL sun': 0.00012457566414400805,
#  'NH clouds DK fog': 1.8741309473429446e-05,
#  'LH fog DK sun': 0.00017169457711141816,
#  'SV clouds LH sun': 0.0009164372092852736,
#  'KR clouds GR fog': 0.0,
#  'AG snow KR rain': 1.7037554066754047e-06,
#  'NH fog PG fog': 3.918637435353431e-05,
#  'GR sun LH clouds': 0.0,
#  'SV sun DR snow': 0.00010526643620168682,
#  'KR snow AA sun': 2.385257569345566e-05,
#  'DK snow RK clouds': 6.045583701106276e-07,
#  'CS sun AA rain': 4.4627399684529944e-05,
#  'MV fog KM clouds': 6.1005435529345135e-05,
#  'AG fog PG fog': 3.792229776148481e-06,
#  'DK snow DR fog': 2.055498458376133e-05,
#  'LH snow DR clouds': 0.00017689744308449143,
#  'KR sun DK clouds': 1.8741309473429446e-05,
#  'DR sun CL sun': 0.00012457566414400805,
#  'LH fog DK rain': 0.00017169457711141816,
#  'CS sun LN snow': 3.293927119572449e-05,
#  'LH sun LH clouds': 0.0015400483280296905,
#  'RK sun GR rain': 0.0,
#  'VB snow RG sun': 3.23896726774421e-05,
#  'KM rain LS fog': 6.265423108419229e-06,
#  'DK clouds CS snow': 3.506438546641639e-05,
#  'NH clouds CS snow': 3.2939271195724485e-05,
#  'VB sun MV clouds': 0.0008097418169360524,
#  'KR fog LS rain': 1.0790450908944226e-05,
#  'NH fog AA fog': 2.385257569345566e-05,
#  'AA snow SP rain': 1.6817714659441087e-05,
#  'AG clouds LS clouds': 1.0442371847365382e-06,
#  'DK rain LN snow': 1.874130947342945e-05,
#  'CL rain RK fog': 3.3342310109131577e-06,
#  'AG snow KR clouds': 1.7037554066754047e-06,
#  'KR clouds AG fog': 2.2716738755672063e-06,
#  'KR rain MV sun': 0.00011358369377836028,
#  'AA fog CS snow': 3.6126942601762336e-05,
#  'RG clouds CS sun': 8.50045708276761e-06,
#  'KR clouds CL clouds': 0.00011358369377836028,
#  'DR rain DK sun': 2.055498458376133e-05,
#  'AA sun NH fog': 2.055498458376133e-05,
#  'PG snow AG fog': 4.763187158447367e-06,
#  'KR fog DK snow': 1.8741309473429446e-05,
#  'LS snow KM sun': 6.265423108419229e-06,
#  'LS clouds NH clouds': 1.1486609032101921e-05,
#  'PG snow SV rain': 0.0002310145771846973,
#  'RG sun AA clouds': 6.155503404762751e-06,
#  'SP sun RK fog': 4.946386664541497e-07,
#  'DK snow DK sun': 1.9950426213650704e-05,
#  'CS fog AA rain': 4.4627399684529944e-05,
#  'CS rain AG sun': 4.2502285413838055e-06,
#  'VB clouds RK rain': 4.0487090846802625e-06,
#  'GR snow NH rain': 0.0,
#  'AA clouds VB fog': 0.0001438848920863293,
#  'PG clouds MV rain': 0.00023815935792236833,
#  'LH sun AG fog': 2.0811463892293114e-05,
#  'MV fog AA fog': 0.00014234601623513865,
#  'KR rain DR snow': 1.930922794232125e-05,
#  'SV fog KM rain': 5.5729289753834195e-05,
#  'CS fog AA fog': 4.4627399684529944e-05,
#  'VB rain AG snow': 1.619483633872105e-05,
#  'DK sun AG rain': 2.4182334804425102e-06,
#  'MV clouds DR clouds': 0.00011523248933320747,
#  'PG rain LN rain': 3.69147004779671e-05,
#  'SV rain SP snow': 8.35939346307513e-05,
#  'AA fog VB snow': 0.0001438848920863293,
#  'DR clouds AG snow': 2.491513282880161e-06,
#  'NH clouds VB sun': 0.00013118916631400614,
#  'KR rain NH clouds': 1.8741309473429446e-05,
#  'GR fog GR sun': 0.0,
#  'AG clouds DR snow': 1.8686349621601212e-06,
#  'RK sun VB fog': 4.2319085907743915e-06,
#  'LN rain SP snow': 1.2365966661353742e-05,
#  'LN rain AA sun': 1.92359481398836e-05,
#  'LH fog LH snow': 0.0015400483280296905,
#  'NH clouds GR snow': 0.0,
#  'RK clouds GR rain': 0.0,
#  'VB sun DR sun': 0.00013765610887912894,
#  'SV snow GR sun': 0.0,
#  'KR snow AG rain': 2.2716738755672063e-06,
#  'CL sun SP clouds': 9.002423729465523e-05,
#  'LS sun NH rain': 1.1486609032101921e-05,
#  'MV rain GR rain': 0.0,
#  'LS sun DR snow': 1.1834688093680766e-05,
#  'AA rain AA sun': 2.6160889470241693e-05,
#  'CS fog AA sun': 4.4627399684529944e-05,
#  'GR sun CL sun': 0.0,
#  'RK snow KM fog': 3.297591109694331e-07,
#  'CL rain LN snow': 0.00010336116133830788,
#  'AG snow SV rain': 1.0662211254678338e-05,
#  'RG fog LH snow': 4.3381643043089876e-05,
#  'NH sun PG sun': 3.918637435353431e-05,
#  'GR rain DK sun': 0.0,
#  'SV rain DR clouds': 0.00010526643620168682,
#  'NH sun AA clouds': 2.385257569345566e-05,
#  'CL sun NH sun': 0.00011002962336013417,
#  'SP rain SV clouds': 9.595990129210503e-05,
#  'RG snow RK clouds': 1.4655960487530363e-07,
#  'AG rain AG clouds': 2.1983940731295544e-07,
#  'DR clouds GR sun': 0.0,
#  'DK fog SP snow': 1.632307599298694e-05,
#  'KR clouds LN clouds': 1.7605472535645848e-05,
#  'SP snow SP rain': 1.335524399426204e-05,
#  'GR rain DR rain': 0.0,
#  'AA clouds RG snow': 4.983026565760322e-06,
#  'RK rain DR snow': 6.228783207200403e-07,
#  'LS clouds NH fog': 1.1486609032101921e-05,
#  'DR fog NH clouds': 2.055498458376133e-05,
#  'SV snow PG rain': 0.0002136289440563644,
#  'SV rain DK fog': 0.00010217036454869602,
#  'LH fog KR fog': 0.00016128884516527166,
#  'GR fog CL clouds': 0.0,
#  'DK snow SV clouds': 0.00011728432380146171,
#  'LN fog DK snow': 1.5113959252765686e-05,
#  'GR sun KR sun': 0.0,
#  'MV fog LH sun': 0.0010032004953714534,
#  'SP sun VB clouds': 0.00011426153195090858,
#  'LS snow NH rain': 1.1486609032101921e-05,
#  'RG sun SP fog': 3.957109331633198e-06,
#  'MV snow PG fog': 0.00023385416952915634,
#  'SV fog LH sun': 0.0009164372092852736,
#  'KR rain RK snow': 5.679184688918016e-07,
#  'LN clouds KM snow': 8.243977774235829e-06,
#  'DK clouds CL snow': 0.00012091167402212549,
#  'SP rain AG fog': 1.978554665816599e-06,
#  'KM clouds LN rain': 1.0222532440052429e-05,
#  'LH fog VB clouds': 0.0012018620397799271,
#  'DK rain SP rain': 1.632307599298694e-05,
#  'PG snow AA clouds': 5.001346516369736e-05,
#  'RG rain RK rain': 1.4655960487530363e-07,
#  'LN clouds GR fog': 0.0,
#  'VB fog CL snow': 0.0008097418169360524,
#  'RK fog DK fog': 6.045583701106275e-07,
#  'VB snow CS rain': 0.00023482512691145522,
#  'SV sun RK clouds': 3.096071652990789e-06,
#  'PG fog CL clouds': 0.00023815935792236833,
#  'RG snow DK snow': 4.83646696088502e-06,
#  'KM clouds MV fog': 6.595182219388663e-05,
#  'SP fog KR fog': 1.5333798660078644e-05,
#  'SV rain RK sun': 3.096071652990789e-06,
#  'KM snow PG sun': 2.2753378656890887e-05,
#  'AG rain GR rain': 0.0,
#  'LH clouds MV sun': 0.0010405731946146557,
#  'AG snow CL fog': 1.0991970365647771e-05,
#  'LN clouds PG sun': 3.160191480123734e-05,
#  'SP clouds LH clouds': 0.0001464130452704283,
#  'LH snow RG snow': 4.162292778458623e-05,
#  'LN fog KR fog': 1.4197961722295037e-05,
#  'GR snow LH sun': 0.0,
#  'NH snow NH clouds': 1.8741309473429446e-05,
#  'LN fog NH clouds': 1.5113959252765686e-05,
#  'CL clouds DR sun': 0.00011336385437104734,
#  'MV snow NH fog': 0.00011184329847046608,
#  'GR sun RK snow': 0.0,
#  'RK fog LS clouds': 3.480790615788461e-07,
#  'RG rain GR sun': 0.0,
#  'SV sun KM snow': 5.5729289753834195e-05,
#  'GR clouds KR sun': 0.0,
#  'CL fog GR fog': 0.0,
#  'PG clouds SP clouds': 3.215151331951972e-05,
#  'NH clouds LH sun': 0.00016810386679197323,
#  'CS rain SP fog': 2.868904265434068e-05,
#  'CL fog AG rain': 1.333692404365263e-05,
#  'RK clouds DK snow': 6.045583701106275e-07,
#  'AA snow MV snow': 0.00012457566414400805,
#  'CS clouds VB clouds': 0.0002454506982649148,
#  'DR snow CL sun': 0.00012457566414400805,
#  'SP snow DK clouds': 1.6323075992986937e-05,
#  'VB sun PG fog': 0.00027936092684293815,
#  'AA rain RK rain': 6.228783207200403e-07,
#  'NH rain LS sun': 1.0790450908944226e-05,
#  'RK rain VB clouds': 4.2319085907743915e-06,
#  'LN snow RG fog': 3.6639901218825906e-06,
#  'DR snow LN rain': 1.9309227942321252e-05,
#  'VB snow RK clouds': 4.0487090846802625e-06,
#  'AG snow RK fog': 5.495985182823886e-08,
#  'AA sun CS sun': 3.6126942601762336e-05,
#  'SP sun GR sun': 0.0,
#  'VB sun LS rain': 7.692547260892499e-05,
#  'MV snow SP clouds': 9.150815329401769e-05,
#  'SV sun LN snow': 9.597822124271446e-05,
#  'RG snow KR fog': 4.5433477511344126e-06,
#  'LH fog CL sun': 0.0010405731946146557,
#  'DK fog LN sun': 1.874130947342945e-05,
#  'CL clouds RK clouds': 3.3342310109131577e-06,
#  'LS sun RK fog': 3.480790615788462e-07,
#  'GR snow KR rain': 0.0,
#  'LS clouds RK clouds': 3.480790615788462e-07,
#  'SP clouds AG snow': 1.978554665816599e-06,
#  'PG sun KR sun': 3.69147004779671e-05,
#  'RK snow RK clouds': 1.8319950609412953e-08,
#  'MV clouds RG clouds': 2.711352690193117e-05,
#  'DK snow MV rain': 0.00012091167402212549,
#  'VB fog CL clouds': 0.0008097418169360524,
#  'AG sun GR clouds': 0.0,
#  'MV snow LN rain': 0.0001050649167449833,
#  'LH fog RK sun': 5.202865973073278e-06,
#  'LN clouds LH fog': 0.00013556763450965585,
#  'CS fog NH rain': 3.506438546641639e-05,
#  'VB fog NH fog': 0.00013360739979444866,
#  'DR rain PG clouds': 4.2978604129682784e-05,
#  'KM sun LN snow': 1.0222532440052429e-05,
#  'KM rain AA fog': 1.384988266071619e-05,
#  'LS sun AA fog': 1.4619320586311533e-05,
#  'AG sun GR fog': 0.0,
#  'CS clouds KM snow': 1.912602843622712e-05,
#  'CL clouds AA sun': 0.00014003770245835255,
#  'MV fog LN sun': 0.0001050649167449833,
#  'VB rain DK clouds': 0.00013360739979444866,
#  'LS rain PG sun': 2.4017455248940376e-05,
#  'KM clouds DR snow': 1.1211809772960727e-05,
#  'LH sun VB sun': 0.0012018620397799271,
#  'SV fog SV fog': 0.000600637900680213,
#  'KR fog KR snow': 1.7605472535645848e-05,
#  'PG rain AA sun': 5.001346516369736e-05,
#  'SV sun SP snow': 8.35939346307513e-05,
#  'LS clouds MV snow': 6.961581231576922e-05,
#  'DK clouds SP rain': 1.632307599298694e-05,
#  'LS snow RK fog': 3.480790615788462e-07,
#  'RG sun LS rain': 2.7846324926307686e-06,
#  'MV fog KM rain': 6.1005435529345135e-05,
#  'CL sun MV snow': 0.0006668462021826314,
#  'MV fog AG sun': 1.3556763450965585e-05,
#  'AG rain CL snow': 1.0991970365647771e-05,
#  'CS fog LH fog': 0.00031451691206240155,
#  'SP clouds NH rain': 1.6323075992986937e-05,
#  'KR clouds VB snow': 0.00013118916631400614,
#  'VB fog CS clouds': 0.00023482512691145522,
#  'DR rain KM clouds': 1.1211809772960727e-05,
#  'RK snow GR fog': 0.0,
#  'AA sun DK rain': 2.055498458376133e-05,
#  'AA rain KM clouds': 1.1211809772960727e-05,
#  'RG sun PG sun': 1.0112612736395948e-05,
#  'SP snow SP clouds': 1.335524399426204e-05,
#  'LH sun RG rain': 4.162292778458623e-05,
#  'VB rain LH rain': 0.0011984178890653576,
#  'SV fog CL snow': 0.0006192143305981577,
#  'SP sun LS clouds': 9.398134662628844e-06,
#  'CS fog PG sun': 7.331644233887064e-05,
#  'DK snow RG fog': 4.8364669608850205e-06,
#  'GR fog LH rain': 0.0,
#  'CL sun PG snow': 0.00023006193975300782,
#  'PG sun DK fog': 3.929629405719077e-05,
#  'CS sun SV clouds': 0.00020613608425711454,
#  'VB snow KM rain': 7.287676352424471e-05,
#  'DK fog DR fog': 2.055498458376133e-05,
#  'AA fog DK rain': 2.055498458376133e-05,
#  'KM sun DK clouds': 1.0882050661991292e-05,
#  'NH clouds LH rain': 0.00016810386679197323,
#  'LS snow KM clouds': 6.265423108419229e-06,
#  'GR rain AG sun': 0.0,
#  'SP rain MV snow': 9.892773329082991e-05,
#  'VB clouds AA snow': 0.00017004578155657102,
#  'RK rain PG fog': 1.2640765920494935e-06,
#  'NH clouds MV clouds': 0.00011358369377836028,
#  'LN clouds LN clouds': 1.4197961722295037e-05,
#  'MV sun DR fog': 0.00011523248933320747,
#  'VB sun NH fog': 0.00013360739979444866,
#  'CS sun KR fog': 3.293927119572449e-05,
#  'SV sun RG rain': 2.476857322392631e-05,
#  'GR clouds GR snow': 0.0,
#  'NH sun CS sun': 3.2939271195724485e-05,
#  'KR snow MV snow': 0.00011358369377836028,
#  'CL snow DR sun': 0.00011336385437104734,
#  'NH rain SP rain': 1.533379866007864e-05,
#  'LH rain DK snow': 0.00017169457711141816,
#  'PG rain LS snow': 2.2625139002624997e-05,
#  'DR sun NH clouds': 2.055498458376133e-05,
#  'AG fog AA rain': 2.3083137767860317e-06,
#  'VB rain LH fog': 0.0011984178890653576,
#  'DR sun AA sun': 2.6160889470241693e-05,
#  'DK sun RK rain': 6.045583701106276e-07,
#  'CS sun DK rain': 3.506438546641639e-05,
#  'CL sun SP fog': 9.002423729465523e-05,
#  'CS sun CL sun': 0.00021251142706919023,
#  'RK rain MV sun': 3.6639901218825906e-06,
#  'RK fog AA rain': 7.694379255953439e-07,
#  'VB fog PG clouds': 0.00027936092684293815,
#  'DR fog KR rain': 1.9309227942321252e-05,
#  'KM snow DR fog': 1.1211809772960727e-05,
#  'LS snow KR snow': 1.079045090894423e-05,
#  'MV snow KM snow': 6.1005435529345135e-05,
#  'RG sun NH snow': 4.83646696088502e-06,
#  'GR rain PG fog': 0.0,
#  'SV rain RG sun': 2.476857322392631e-05,
#  'AG sun SP clouds': 1.483915999362449e-06,
#  'LH rain DR fog': 0.00017689744308449143,
#  'LH fog SP sun': 0.00014047738127297848,
#  'KM fog PG sun': 2.2753378656890887e-05,
#  'LS sun KR fog': 1.079045090894423e-05,
#  'MV sun LN rain': 0.0001050649167449833,
#  'PG rain VB fog': 0.00027507405840033545,
#  'KM clouds DK fog': 1.0882050661991292e-05,
#  'CS snow VB snow': 0.0002454506982649148,
#  'AG sun SP snow': 1.483915999362449e-06,
#  'CS fog RK rain': 1.0625571353459514e-06,
#  'NH snow CL sun': 0.00011358369377836028,
#  'VB fog AA snow': 0.00017004578155657102,
#  'DK sun DK snow': 1.9950426213650704e-05,
#  'SP fog CS rain': 2.8689042654340678e-05,
#  'MV rain GR fog': 0.0,
#  'GR fog MV clouds': 0.0,
#  'CL clouds LS fog': 6.335038920734998e-05,
#  'RK rain KM snow': 3.297591109694331e-07,
#  'NH fog SP clouds': 1.533379866007864e-05,
#  'LS rain AA clouds': 1.4619320586311533e-05,
#  'MV snow KR sun': 0.0001050649167449833,
#  'NH sun KM rain': 1.0222532440052427e-05,
#  'SV rain GR fog': 0.0,
#  'LN rain MV sun': 9.159975304706474e-05,
#  'CS clouds DK clouds': 3.506438546641639e-05,
#  'KM snow DK clouds': 1.0882050661991292e-05,
#  'AG fog MV clouds': 1.0991970365647771e-05,
#  'LS snow NH clouds': 1.1486609032101921e-05,
#  'CL fog CS rain': 0.00019338539863296308,
#  'CS snow DR clouds': 3.612694260176234e-05,
#  'AG snow LS sun': 1.0442371847365382e-06,
#  'SV snow NH fog': 0.00010217036454869602,
#  'SP clouds LN rain': 1.5333798660078644e-05,
#  'CL rain LH sun': 0.0009869323792302943,
#  'PG rain DR rain': 4.048709084680262e-05,
#  'NH clouds RG snow': 4.5433477511344126e-06,
#  'MV sun LN clouds': 0.0001050649167449833,
#  'PG snow PG fog': 8.21649784832171e-05,
#  'LN sun LH clouds': 0.00013556763450965585,
#  'KR fog SV clouds': 0.00011017618296500949,
#  'SP rain CS snow': 2.8689042654340678e-05,
#  'NH sun VB sun': 0.00013118916631400614,
#  'PG clouds LN rain': 3.69147004779671e-05,
#  'RG rain PG snow': 1.0112612736395948e-05,
#  'KM clouds LH rain': 9.760869684695219e-05,
#  'RG sun AA fog': 6.155503404762751e-06,
#  'KR clouds GR snow': 0.0,
#  'KR rain AA sun': 2.385257569345566e-05,
#  'RG snow LN rain': 4.5433477511344126e-06,
#  'RK clouds PG sun': 1.2640765920494935e-06,
#  'DK snow CS snow': 3.506438546641639e-05,
#  'KM sun PG sun': 2.2753378656890887e-05,
#  'SP snow VB rain': 0.00011426153195090858,
#  'GR snow LS snow': 0.0,
#  'AA snow PG clouds': 4.2978604129682784e-05,
#  'SV rain SV snow': 0.000600637900680213,
#  'GR fog DR sun': 0.0,
#  'SV sun AA rain': 0.00013003500942561312,
#  'DK sun LN rain': 1.874130947342945e-05,
#  'RK fog CS snow': 1.0625571353459512e-06,
#  'MV rain AG clouds': 1.3556763450965585e-05,
#  'KM rain LS snow': 6.265423108419229e-06,
#  'CL sun CL clouds': 0.0006668462021826314,
#  'RG sun DK rain': 4.83646696088502e-06,
#  'CL sun CL snow': 0.0006668462021826314,
#  'LH snow RG fog': 4.162292778458623e-05,
#  'DK sun GR snow': 0.0,
#  'KM snow KR snow': 1.0222532440052429e-05,
#  'AG clouds NH fog': 1.8136751103318824e-06,
#  'GR clouds GR sun': 0.0,
#  'RG snow MV sun': 2.9311920975060725e-05,
#  'DR snow SP sun': 1.6817714659441087e-05,
#  'SV snow RK fog': 3.096071652990789e-06,
#  'PG rain SP fog': 3.215151331951972e-05,
#  'SV snow DR clouds': 0.00010526643620168682,
#  'RG fog MV fog': 2.9311920975060725e-05,
#  'VB rain SP clouds': 0.00010931514528636708,
#  'GR rain RK clouds': 0.0,
#  'SV fog MV clouds': 0.0006192143305981577,
#  'VB clouds DR rain': 0.00013765610887912894,
#  'CL rain SP rain': 9.002423729465523e-05,
#  'DR snow DK rain': 2.055498458376133e-05,
#  'CL rain SP snow': 9.002423729465523e-05,
#  'CL clouds NH snow': 0.00011002962336013417,
#  'SV snow GR snow': 0.0,
#  'SP fog LS snow': 9.398134662628844e-06,
#  'CS sun KM rain': 1.912602843622712e-05,
#  'KR rain DR rain': 1.930922794232125e-05,
#  'VB sun GR fog': 0.0,
#  'CL rain RK snow': 3.3342310109131577e-06,
#  'RG rain KR sun': 4.5433477511344126e-06,
#  'SV fog CL rain': 0.0006192143305981577,
#  'SP sun RK clouds': 4.946386664541497e-07,
#  'NH fog AG sun': 2.2716738755672063e-06,
#  'AA clouds CL clouds': 0.00012457566414400805,
#  'MV fog SV snow': 0.0006575030273718309,
#  'CL rain DR fog': 0.00011336385437104734,
#  'SV clouds SP clouds': 8.35939346307513e-05,
#  'LN sun RK rain': 4.579987652353238e-07,
#  'DK fog GR rain': 0.0,
#  'SV snow DR fog': 0.00010526643620168682,
#  'LH rain PG snow': 0.00035899775214205616,
#  'CL snow LN clouds': 0.00010336116133830788,
#  'PG fog LS rain': 2.2625139002624997e-05,
#  'SP rain DR fog': 1.681771465944109e-05,
#  'NH fog KR rain': 1.7605472535645848e-05,
#  'LH sun SP snow': 0.00014047738127297848,
#  'PG fog LN snow': 3.69147004779671e-05,
#  'SV snow KM rain': 5.5729289753834195e-05,
#  'PG rain DK clouds': 3.929629405719077e-05,
#  'PG clouds LN fog': 3.69147004779671e-05,
#  'DK snow NH fog': 1.9950426213650704e-05,
#  'SP rain PG snow': 3.413006798533633e-05,
#  'CS clouds CS fog': 6.162831385006517e-05,
#  'DR clouds DR sun': 2.117786290448137e-05,
#  'KM sun LS snow': 6.265423108419229e-06,
#  'MV rain SV snow': 0.0006575030273718309,
#  'LH sun MV fog': 0.0010405731946146557,
#  'CS snow VB fog': 0.0002454506982649148,
#  'LS rain CL sun': 6.961581231576922e-05,
#  'NH rain KM clouds': 1.0222532440052427e-05,
#  'DR clouds LS clouds': 1.1834688093680766e-05,
#  'CL clouds GR sun': 0.0,
#  'NH snow SV rain': 0.00011017618296500949,
#  'SV sun CS fog': 0.00017957215587346574,
#  'CS snow LH fog': 0.00031451691206240155,
#  'CS rain KM fog': 1.912602843622712e-05,
#  'DR snow DK snow': 2.055498458376133e-05,
#  'SV sun LH fog': 0.0009164372092852736,
#  'SV clouds GR sun': 0.0,
#  'MV snow CS rain': 0.00019657307003900096,
#  'DK sun SP rain': 1.632307599298694e-05,
#  'KR fog RG clouds': 4.5433477511344126e-06,
#  'RK clouds DK clouds': 6.045583701106275e-07,
#  'SP sun AA rain': 2.0774823991074287e-05,
#  'DR clouds VB clouds': 0.0001438848920863293,
#  'KM sun KR rain': 1.0222532440052429e-05,
#  'CS fog VB sun': 0.0002454506982649148,
#  'AG snow RK snow': 5.495985182823886e-08,
#  'PG fog LN rain': 3.69147004779671e-05,
#  'VB clouds CS rain': 0.00023482512691145522,
#  'LH sun CL snow': 0.0010405731946146557,
#  'RK rain KM sun': 3.297591109694331e-07,
#  'LS clouds CL clouds': 6.961581231576922e-05,
#  'CS fog KR snow': 3.293927119572449e-05,
#  'DK fog CS snow': 3.506438546641639e-05,
#  'RK fog CL clouds': 3.6639901218825906e-06,
#  'DK rain AA clouds': 2.539145154464635e-05,
#  'LH sun AA clouds': 0.00021852037086907765,
#  'AG sun VB snow': 1.2695725772323172e-05,
#  'MV fog DR rain': 0.00011523248933320747,
#  'LH clouds KM snow': 9.3651587515319e-05,
#  'VB clouds NH rain': 0.00013360739979444866,
#  'CS snow RG sun': 8.500457082767611e-06,
#  'AG sun CS rain': 3.1876714060378533e-06,
#  'RG snow VB sun': 3.385526872619513e-05,
#  'KM sun CL snow': 6.595182219388663e-05,
#  'CL fog DK sun': 0.00011002962336013417,
#  'NH snow DK fog': 1.8741309473429446e-05,
#  'KM sun NH fog': 1.0882050661991292e-05,
#  'CL snow RK rain': 3.3342310109131577e-06,
#  'RK clouds DK sun': 6.045583701106275e-07,
#  'VB fog NH clouds': 0.00013360739979444866,
#  'AA rain CL sun': 0.00012457566414400805,
#  'DK fog CL sun': 0.00012091167402212549,
#  'CL rain SV snow': 0.0006468408161171525,
#  'DR fog GR sun': 0.0,
#  'LH clouds CS snow': 0.0003017662264382501,
#  'LH rain RG clouds': 4.162292778458623e-05,
#  'DR rain AA fog': 2.6160889470241693e-05,
#  'LH fog KM rain': 9.3651587515319e-05,
#  'PG clouds PG rain': 8.21649784832171e-05,
#  'CL sun KM rain': 6.001615819643683e-05,
#  'CL sun CS fog': 0.00019338539863296308,
#  'LN rain DK snow': 1.5113959252765686e-05,
#  'SV fog DR fog': 0.00010526643620168682,
#  'NH sun LH clouds': 0.00016810386679197323,
#  'NH snow VB snow': 0.00013118916631400614,
#  'DK rain AG clouds': 2.4182334804425102e-06,
#  'PG clouds CS rain': 6.906621379748681e-05,
#  'AA rain LN snow': 1.9309227942321252e-05,
#  'AG rain VB clouds': 1.2695725772323172e-05,
#  'CL rain MV snow': 0.0006668462021826314,
#  'LN sun NH rain': 1.5113959252765686e-05,
#  'VB clouds CS snow': 0.00023482512691145522,
#  'VB snow KR rain': 0.00012550998162508815,
#  'RK snow SP snow': 4.946386664541497e-07,
#  'NH fog GR rain': 0.0,
#  'CS fog LN rain': 3.293927119572449e-05,
#  'CL rain KM fog': 6.001615819643683e-05,
#  'LH snow PG fog': 0.00035899775214205616,
#  'RK sun AG sun': 7.327980243765181e-08,
#  'PG snow SV sun': 0.0002310145771846973,
#  'AA rain SP snow': 1.6817714659441087e-05,
#  'PG sun NH fog': 3.929629405719077e-05,
#  'DR sun CS rain': 3.6126942601762336e-05,
#  'LN sun LH fog': 0.00013556763450965585,
#  'SP sun KR fog': 1.5333798660078644e-05,
#  'DK clouds AG fog': 2.4182334804425102e-06,
#  'SV snow DK fog': 0.00010217036454869602,
#  'LN snow KR sun': 1.4197961722295037e-05,
#  'DR sun RG fog': 4.983026565760322e-06,
#  'KR clouds AG clouds': 2.2716738755672063e-06,
#  'NH clouds AA clouds': 2.385257569345566e-05,
#  'RG rain PG rain': 1.0112612736395948e-05,
#  'NH snow CS snow': 3.2939271195724485e-05,
#  'DK clouds CL rain': 0.00012091167402212549,
#  'DK snow NH clouds': 1.9950426213650704e-05,
#  'PG rain CL rain': 0.00023815935792236833,
#  'SV rain LN clouds': 9.597822124271446e-05,
#  'RK snow VB snow': 4.2319085907743915e-06,
#  'RK clouds GR fog': 0.0,
#  'GR snow NH fog': 0.0,
#  'SP sun SV snow': 9.595990129210503e-05,
#  'SP snow KM clouds': 8.903495996174692e-06,
#  'LH snow GR fog': 0.0,
#  'AG clouds DR fog': 1.8686349621601212e-06,
#  'RK sun PG snow': 1.2640765920494935e-06,
#  'LN rain AA snow': 1.92359481398836e-05,
#  'VB clouds RG snow': 3.23896726774421e-05,
#  'DR sun CS sun': 3.6126942601762336e-05,
#  'LN sun VB clouds': 0.00010579771476935979,
#  'AA fog AG fog': 2.491513282880161e-06,
#  'CS snow PG clouds': 7.331644233887064e-05,
#  'NH clouds PG fog': 3.918637435353431e-05,
#  'RK fog CL rain': 3.6639901218825906e-06,
#  'CL rain MV fog': 0.0006668462021826314,
#  'KM rain CL rain': 6.595182219388663e-05,
#  'NH rain LN rain': 1.7605472535645848e-05,
#  'SV snow SV sun': 0.000600637900680213,
#  'GR clouds LH snow': 0.0,
#  'LH rain RK rain': 5.202865973073278e-06,
#  'RG fog VB sun': 3.385526872619513e-05,
#  'AA snow NH rain': 2.055498458376133e-05,
#  'PG snow MV snow': 0.00023815935792236833,
#  'PG clouds DK snow': 3.929629405719077e-05,
#  'CL sun MV fog': 0.0006668462021826314,
#  'AG fog AG fog': 2.1983940731295544e-07,
#  'GR snow DR clouds': 0.0,
#  'SV fog RG rain': 2.476857322392631e-05,
#  'LH rain SV clouds': 0.0010093559987762158,
#  'LS sun GR snow': 0.0,
#  'RG rain SV rain': 2.8432563345808904e-05,
#  'MV rain DR fog': 0.00011523248933320747,
#  'AA sun PG rain': 4.2978604129682784e-05,
#  'VB sun RK snow': 4.0487090846802625e-06,
#  'RK clouds GR clouds': 0.0,
#  'MV snow PG clouds': 0.00023385416952915634,
#  'GR fog RK fog': 0.0,
#  'LN sun AA rain': 1.92359481398836e-05,
#  'SP fog SP fog': 1.335524399426204e-05,
#  'KR sun PG sun': 3.918637435353431e-05,
#  'AA clouds RK rain': 6.228783207200403e-07,
#  'KM snow LH fog': 9.760869684695219e-05,
#  'GR clouds PG fog': 0.0,
#  'KM sun RK snow': 3.297591109694332e-07,
#  'DK clouds KM snow': 1.0882050661991292e-05,
#  'DK rain LS rain': 1.1486609032101921e-05,
#  'CL sun GR rain': 0.0,
#  'SP fog VB snow': 0.00011426153195090858,
#  'LH rain AA rain': 0.00021852037086907765,
#  'CS fog KR sun': 3.293927119572449e-05,
#  'LH sun DR sun': 0.00017689744308449143,
#  'CS rain GR snow': 0.0,
#  'GR rain MV snow': 0.0,
#  'MV clouds SP rain': 9.150815329401769e-05,
#  'CL sun RK snow': 3.3342310109131577e-06,
#  'SP rain SP sun': 1.335524399426204e-05,
#  'SP sun GR rain': 0.0,
#  'KR rain DK sun': 1.8741309473429446e-05,
#  'CL fog NH rain': 0.00011002962336013417,
#  'LH sun MV snow': 0.0010405731946146557,
#  'RG snow AA clouds': 6.155503404762751e-06,
#  'LN rain DR sun': 1.557195801800101e-05,
#  'AA snow LN sun': 1.9309227942321252e-05,
#  'KR rain CL clouds': 0.00011358369377836028,
#  'DK clouds AA sun': 2.539145154464635e-05,
#  'MV rain RK fog': 3.3891908627413963e-06,
#  'PG sun LS clouds': 2.2625139002624997e-05,
#  'RG sun CL clouds': 2.9311920975060725e-05,
#  'DR snow SV rain': 0.00012083839421968782,
#  'RK snow KM rain': 3.297591109694331e-07,
#  'NH fog CS clouds': 3.2939271195724485e-05,
#  'LN clouds SV rain': 8.885176045565283e-05,
#  'GR rain LS fog': 0.0,
#  'LH clouds VB rain': 0.0012018620397799271,
#  'DK fog RK fog': 6.045583701106276e-07,
#  'LS sun AG snow': 1.3923162463153847e-06,
#  'AA sun CS snow': 3.6126942601762336e-05,
#  'SV clouds VB rain': 0.0007151925518408722,
#  'SP fog GR fog': 0.0,
#  'CS rain CS snow': 6.162831385006517e-05,
#  'PG sun MV rain': 0.00023815935792236833,
#  'NH clouds LS fog': 1.0790450908944226e-05,
#  'SP sun KM fog': 8.903495996174692e-06,
#  'DK rain AG snow': 2.4182334804425102e-06,
#  'RK fog KR snow': 5.679184688918016e-07,
#  'LN fog CL snow': 9.159975304706474e-05,
#  'GR fog KR snow': 0.0,
#  'AG fog SV clouds': 1.0662211254678338e-05,
#  'VB sun DK fog': 0.00013360739979444866,
#  'LN fog KR sun': 1.4197961722295037e-05,
#  'RK rain KR sun': 5.679184688918016e-07,
#  'KM fog CS snow': 1.912602843622712e-05,
#  'DR snow KR snow': 1.9309227942321252e-05,
#  'VB sun AA fog': 0.00017004578155657102,
#  'PG sun KR snow': 3.69147004779671e-05,
#  'PG rain SP clouds': 3.215151331951972e-05,
#  'LS sun GR sun': 0.0,
#  'KM fog PG rain': 2.2753378656890887e-05,
#  'DK fog KM rain': 1.0882050661991292e-05,
#  'LN fog RK clouds': 4.579987652353238e-07,
#  'PG snow CL clouds': 0.00023815935792236833,
#  'LS rain NH sun': 1.1486609032101921e-05,
#  'SV rain SV rain': 0.000600637900680213,
#  'DK snow CS sun': 3.506438546641639e-05,
#  'DK snow LN clouds': 1.874130947342945e-05,
#  'AG rain AG snow': 2.1983940731295544e-07,
#  'MV snow SV rain': 0.0006575030273718309,
#  'CL rain CS snow': 0.00019338539863296308,
#  'MV snow DK clouds': 0.00011184329847046608,
#  'DK rain PG rain': 4.1714527537633295e-05,
#  'VB rain AG clouds': 1.619483633872105e-05,
#  'LS sun SV rain': 6.752733794629614e-05,
#  'KM fog SV rain': 6.397326752807003e-05,
#  'CS sun DR snow': 3.612694260176234e-05,
#  'SP fog SV fog': 9.595990129210503e-05,
#  'CS clouds LN rain': 3.293927119572449e-05,
#  'KR snow CS sun': 3.2939271195724485e-05,
#  'SV sun RK rain': 3.096071652990789e-06,
#  'DK rain LN sun': 1.874130947342945e-05,
#  'NH sun RK snow': 5.679184688918016e-07,
#  'RG rain DK snow': 4.83646696088502e-06,
#  'CL fog LN sun': 0.00010336116133830788,
#  'CL snow DK rain': 0.00011002962336013417,
#  'VB rain DR sun': 0.00013765610887912894,
#  'VB rain GR snow': 0.0,
#  'SP fog LS clouds': 9.398134662628844e-06,
#  'SV sun NH clouds': 0.00010217036454869602,
#  'CS rain PG snow': 7.331644233887064e-05,
#  'RG snow LN sun': 4.5433477511344126e-06,
#  'AA sun LN clouds': 1.9309227942321252e-05,
#  'RG fog SP clouds': 3.957109331633198e-06,
#  'KM snow RK rain': 3.297591109694332e-07,
#  'LH clouds CL rain': 0.0010405731946146557,
#  'SP rain LS fog': 9.398134662628844e-06,
#  'SP sun MV clouds': 9.892773329082991e-05,
#  'PG rain LS clouds': 2.2625139002624997e-05,
#  'GR snow SV snow': 0.0,
#  'MV clouds PG clouds': 0.00023385416952915634,
#  'NH sun SP rain': 1.533379866007864e-05,
#  'NH snow AA clouds': 2.385257569345566e-05,
#  'LS sun NH snow': 1.1486609032101921e-05,
#  'LH fog RG clouds': 4.162292778458623e-05,
#  'GR fog KM sun': 0.0,
#  'RK fog KR fog': 5.679184688918016e-07,
#  'PG clouds AG fog': 4.763187158447367e-06,
#  'AG sun PG snow': 3.792229776148481e-06,
#  'MV rain KM clouds': 6.1005435529345135e-05,
#  'AA snow PG rain': 4.2978604129682784e-05,
#  'VB sun KR snow': 0.00012550998162508815,
#  'SP fog PG snow': 3.413006798533633e-05,
#  'AA snow AG fog': 2.491513282880161e-06,
#  'NH snow AA rain': 2.385257569345566e-05,
#  'LN clouds NH fog': 1.5113959252765686e-05,
#  'DR sun VB snow': 0.0001438848920863293,
#  'CL snow AA sun': 0.00014003770245835255,
#  'KR snow CL rain': 0.00011358369377836028,
#  'LH snow AG snow': 2.0811463892293114e-05,
#  'RG sun GR sun': 0.0,
#  'RG fog CS snow': 8.50045708276761e-06,
#  'PG rain KM clouds': 2.143434221301315e-05,
#  'GR snow RK clouds': 0.0,
#  'CL clouds PG sun': 0.00023006193975300782,
#  'LN snow LH rain': 0.00013556763450965585,
#  'AG rain NH clouds': 1.8136751103318824e-06,
#  'SV fog SP snow': 8.35939346307513e-05,
#  'LS rain PG clouds': 2.4017455248940376e-05,
#  'RG fog PG fog': 1.0112612736395948e-05,
#  'RK rain NH fog': 6.045583701106275e-07,
#  'AA clouds LN snow': 1.9309227942321252e-05,
#  'GR sun VB snow': 0.0,
#  'PG clouds GR rain': 0.0,
#  'SV rain NH clouds': 0.00010217036454869602,
#  'NH rain NH rain': 1.8741309473429446e-05,
#  'LN clouds RG snow': 3.6639901218825906e-06,
#  'RK clouds KR sun': 5.679184688918016e-07,
#  'AG fog LH sun': 1.6268116141158703e-05,
#  'DR clouds RK rain': 6.228783207200403e-07,
#  'MV fog VB rain': 0.0007829030892932624,
#  'SP rain AA clouds': 2.0774823991074287e-05,
#  'DR clouds AA snow': 2.6160889470241693e-05,
#  'SP snow AA rain': 2.0774823991074287e-05,
#  'LN clouds LS snow': 8.701976539471152e-06,
#  'AG fog CL sun': 1.0991970365647771e-05,
#  'CS rain DR rain': 3.612694260176234e-05,
#  'CL sun LN sun': 0.00010336116133830788,
#  'SV snow KM fog': 5.5729289753834195e-05,
#  'AA sun AG clouds': 2.491513282880161e-06,
#  'SV rain LH sun': 0.0009164372092852736,
#  'DK rain NH sun': 1.9950426213650704e-05,
#  'DK sun SV clouds': 0.00011728432380146171,
#  'LH sun SV rain': 0.0010093559987762158,
#  'SP clouds KR snow': 1.5333798660078644e-05,
#  'SV rain AA sun': 0.00013003500942561312,
#  'NH sun PG snow': 3.918637435353431e-05,
#  'MV rain CS snow': 0.00019657307003900096,
#  'NH rain DK snow': 1.8741309473429446e-05,
#  'SP snow SP fog': 1.335524399426204e-05,
#  'LH rain LN clouds': 0.00016128884516527166,
#  'SV fog RK sun': 3.096071652990789e-06,
#  'RK fog SV snow': 3.554070418226113e-06,
#  'CL rain CL clouds': 0.0006668462021826314,
#  'AG sun SP fog': 1.483915999362449e-06,
#  'CL fog KR rain': 0.00010336116133830788,
#  'MV rain SP fog': 9.150815329401769e-05,
#  'KR clouds LH snow': 0.00016810386679197323,
#  'KM snow GR clouds': 0.0,
#  'PG clouds DR fog': 4.048709084680262e-05,
#  'KR sun AG snow': 2.2716738755672063e-06,
#  'RK snow DK sun': 6.045583701106275e-07,
#  'SV clouds NH clouds': 0.00010217036454869602,
#  'PG fog RG clouds': 9.526374316894734e-06,
#  'RG fog MV rain': 2.9311920975060725e-05,
#  'RG sun LS snow': 2.7846324926307686e-06,
#  'LH snow GR snow': 0.0,
#  'CL fog LN fog': 0.00010336116133830788,
#  'DR clouds CS clouds': 3.6126942601762336e-05,
#  'CS clouds RG sun': 8.500457082767611e-06,
#  'NH fog AA snow': 2.385257569345566e-05,
#  'DK rain KM sun': 1.0882050661991292e-05,
#  'CL rain NH fog': 0.00011002962336013417,
#  'LS rain GR rain': 0.0,
#  'LS rain NH rain': 1.1486609032101921e-05,
#  'KR clouds NH rain': 1.8741309473429446e-05,
#  'LN clouds LS rain': 8.701976539471152e-06,
#  'AG rain LH rain': 1.6268116141158703e-05,
#  'CS rain LS snow': 2.0188585571573077e-05,
#  'AA snow LN fog': 1.9309227942321252e-05,
#  'SV rain CS sun': 0.00017957215587346574,
#  'DK clouds SP fog': 1.632307599298694e-05,
#  'SV sun MV sun': 0.0006192143305981577,
#  'DK rain SV rain': 0.00011728432380146171,
#  'SV clouds NH rain': 0.00010217036454869602,
#  'KM sun AA snow': 1.384988266071619e-05,
#  'AA snow DR clouds': 2.117786290448137e-05,
#  'CL sun PG sun': 0.00023006193975300782,
#  'LN clouds RK snow': 4.579987652353238e-07,
#  'SP snow LH fog': 0.0001464130452704283,
#  'VB fog DR rain': 0.00013765610887912894,
#  'MV rain KR sun': 0.0001050649167449833,
#  'KR sun PG fog': 3.918637435353431e-05,
#  'MV sun RK clouds': 3.3891908627413963e-06,
#  'LH clouds GR snow': 0.0,
#  'SV fog SP fog': 8.35939346307513e-05,
#  'LS rain GR clouds': 0.0,
#  'VB fog KR snow': 0.00012550998162508815,
#  'SV fog GR sun': 0.0,
#  'RK rain RK snow': 1.8319950609412953e-08,
#  'GR rain AG fog': 0.0,
#  'RG snow MV clouds': 2.9311920975060725e-05,
#  'LS sun LS fog': 6.613502169998075e-06,
#  'GR snow AG fog': 0.0,
#  'SV clouds GR clouds': 0.0,
#  'RG rain KR snow': 4.5433477511344126e-06,
#  'SV rain AG sun': 1.2384286611963155e-05,
#  'RG fog CS fog': 8.50045708276761e-06,
#  'RK fog CL fog': 3.6639901218825906e-06,
#  ...}

# %%
# Mercedes winning one of the races on a rainy day 
def MercedesRain(outcome): return ('LH rain' in outcome or 'VB rain' in outcome)
such_that(MercedesRain,SRWC)
# Out:
# {'AA clouds LH rain': 0.0013678800984590967,
#  'AA clouds VB rain': 0.0010675010227839572,
#  'AA fog LH rain': 0.0013678800984590967,
#  'AA fog VB rain': 0.0010675010227839572,
#  'AA rain LH rain': 0.0013678800984590967,
#  'AA rain VB rain': 0.0010675010227839572,
#  'AA snow LH rain': 0.0013678800984590967,
#  'AA snow VB rain': 0.0010675010227839572,
#  'AA sun LH rain': 0.0013678800984590967,
#  'AA sun VB rain': 0.0010675010227839572,
#  'AG clouds LH rain': 0.00012069530280521444,
#  'AG clouds VB rain': 9.41912667162315e-05,
#  'AG fog LH rain': 0.00012069530280521444,
#  'AG fog VB rain': 9.41912667162315e-05,
#  'AG rain LH rain': 0.00012069530280521444,
#  'AG rain VB rain': 9.41912667162315e-05,
#  'AG snow LH rain': 0.00012069530280521444,
#  'AG snow VB rain': 9.41912667162315e-05,
#  'AG sun LH rain': 0.00012069530280521444,
#  'AG sun VB rain': 9.41912667162315e-05,
#  'CL clouds LH rain': 0.00732218170351634,
#  'CL clouds VB rain': 0.0057142701807847114,
#  'CL fog LH rain': 0.00732218170351634,
#  'CL fog VB rain': 0.0057142701807847114,
#  'CL rain LH rain': 0.00732218170351634,
#  'CL rain VB rain': 0.0057142701807847114,
#  'CL snow LH rain': 0.00732218170351634,
#  'CL snow VB rain': 0.0057142701807847114,
#  'CL sun LH rain': 0.00732218170351634,
#  'CL sun VB rain': 0.0057142701807847114,
#  'CS clouds LH rain': 0.0023334425209008123,
#  'CS clouds VB rain': 0.0018210311565138098,
#  'CS fog LH rain': 0.0023334425209008123,
#  'CS fog VB rain': 0.0018210311565138098,
#  'CS rain LH rain': 0.0023334425209008123,
#  'CS rain VB rain': 0.0018210311565138098,
#  'CS snow LH rain': 0.0023334425209008123,
#  'CS snow VB rain': 0.0018210311565138098,
#  'CS sun LH rain': 0.0023334425209008123,
#  'CS sun VB rain': 0.0018210311565138098,
#  'DK clouds LH rain': 0.0013276483308573585,
#  'DK clouds VB rain': 0.001036103933878547,
#  'DK fog LH rain': 0.0013276483308573585,
#  'DK fog VB rain': 0.001036103933878547,
#  'DK rain LH rain': 0.0013276483308573585,
#  'DK rain VB rain': 0.001036103933878547,
#  'DK snow LH rain': 0.0013276483308573585,
#  'DK snow VB rain': 0.001036103933878547,
#  'DK sun LH rain': 0.0013276483308573585,
#  'DK sun VB rain': 0.001036103933878547,
#  'DR clouds LH rain': 0.0013678800984590967,
#  'DR clouds VB rain': 0.0010675010227839572,
#  'DR fog LH rain': 0.0013678800984590967,
#  'DR fog VB rain': 0.0010675010227839572,
#  'DR rain LH rain': 0.0013678800984590967,
#  'DR rain VB rain': 0.0010675010227839572,
#  'DR snow LH rain': 0.0013678800984590967,
#  'DR snow VB rain': 0.0010675010227839572,
#  'DR sun LH rain': 0.0013678800984590967,
#  'DR sun VB rain': 0.0010675010227839572,
#  'GR clouds LH rain': 0.0,
#  'GR clouds VB rain': 0.0,
#  'GR fog LH rain': 0.0,
#  'GR fog VB rain': 0.0,
#  'GR rain LH rain': 0.0,
#  'GR rain VB rain': 0.0,
#  'GR snow LH rain': 0.0,
#  'GR snow VB rain': 0.0,
#  'GR sun LH rain': 0.0,
#  'GR sun VB rain': 0.0,
#  'KM clouds LH rain': 0.0007241718168312864,
#  'KM clouds VB rain': 0.0005651476002973892,
#  'KM fog LH rain': 0.0007241718168312864,
#  'KM fog VB rain': 0.0005651476002973892,
#  'KM rain LH rain': 0.0007241718168312864,
#  'KM rain VB rain': 0.0005651476002973892,
#  'KM snow LH rain': 0.0007241718168312864,
#  'KM snow VB rain': 0.0005651476002973892,
#  'KM sun LH rain': 0.0007241718168312864,
#  'KM sun VB rain': 0.0005651476002973892,
#  'KR clouds LH rain': 0.0012471847956538821,
#  'KR clouds VB rain': 0.0009733097560677257,
#  'KR fog LH rain': 0.0012471847956538821,
#  'KR fog VB rain': 0.0009733097560677257,
#  'KR rain LH rain': 0.0012471847956538821,
#  'KR rain VB rain': 0.0009733097560677257,
#  'KR snow LH rain': 0.0012471847956538821,
#  'KR snow VB rain': 0.0009733097560677257,
#  'KR sun LH rain': 0.0012471847956538821,
#  'KR sun VB rain': 0.0009733097560677257,
#  'LH clouds LH rain': 0.011425821998893632,
#  'LH clouds VB rain': 0.008916773249136582,
#  'LH fog LH rain': 0.011425821998893632,
#  'LH fog VB rain': 0.008916773249136582,
#  'LH rain AA clouds': 0.001621231499843015,
#  'LH rain AA fog': 0.001621231499843015,
#  'LH rain AA rain': 0.001621231499843015,
#  'LH rain AA snow': 0.001621231499843015,
#  'LH rain AA sun': 0.001621231499843015,
#  'LH rain AG clouds': 0.00015440299998504907,
#  'LH rain AG fog': 0.00015440299998504907,
#  'LH rain AG rain': 0.00015440299998504907,
#  'LH rain AG snow': 0.00015440299998504907,
#  'LH rain AG sun': 0.00015440299998504907,
#  'LH rain CL clouds': 0.007720149999252454,
#  'LH rain CL fog': 0.007720149999252454,
#  'LH rain CL rain': 0.007720149999252454,
#  'LH rain CL snow': 0.007720149999252454,
#  'LH rain CL sun': 0.007720149999252454,
#  'LH rain CS clouds': 0.0022388434997832117,
#  'LH rain CS fog': 0.0022388434997832117,
#  'LH rain CS rain': 0.0022388434997832117,
#  'LH rain CS snow': 0.0022388434997832117,
#  'LH rain CS sun': 0.0022388434997832117,
#  'LH rain DK clouds': 0.0012738247498766547,
#  'LH rain DK fog': 0.0012738247498766547,
#  'LH rain DK rain': 0.0012738247498766547,
#  'LH rain DK snow': 0.0012738247498766547,
#  'LH rain DK sun': 0.0012738247498766547,
#  'LH rain DR clouds': 0.001312425499872917,
#  'LH rain DR fog': 0.001312425499872917,
#  'LH rain DR rain': 0.001312425499872917,
#  'LH rain DR snow': 0.001312425499872917,
#  'LH rain DR sun': 0.001312425499872917,
#  'LH rain GR clouds': 0.0,
#  'LH rain GR fog': 0.0,
#  'LH rain GR rain': 0.0,
#  'LH rain GR snow': 0.0,
#  'LH rain GR sun': 0.0,
#  'LH rain KM clouds': 0.0006948134999327208,
#  'LH rain KM fog': 0.0006948134999327208,
#  'LH rain KM rain': 0.0006948134999327208,
#  'LH rain KM snow': 0.0006948134999327208,
#  'LH rain KM sun': 0.0006948134999327208,
#  'LH rain KR clouds': 0.0011966232498841307,
#  'LH rain KR fog': 0.0011966232498841307,
#  'LH rain KR rain': 0.0011966232498841307,
#  'LH rain KR snow': 0.0011966232498841307,
#  'LH rain KR sun': 0.0011966232498841307,
#  'LH rain LH clouds': 0.011425821998893632,
#  'LH rain LH fog': 0.011425821998893632,
#  'LH rain LH rain': 0.011425821998893632,
#  'LH rain LH snow': 0.011425821998893632,
#  'LH rain LH sun': 0.011425821998893632,
#  'LH rain LN clouds': 0.0011966232498841307,
#  'LH rain LN fog': 0.0011966232498841307,
#  'LH rain LN rain': 0.0011966232498841307,
#  'LH rain LN snow': 0.0011966232498841307,
#  'LH rain LN sun': 0.0011966232498841307,
#  'LH rain LS clouds': 0.0007334142499289829,
#  'LH rain LS fog': 0.0007334142499289829,
#  'LH rain LS rain': 0.0007334142499289829,
#  'LH rain LS snow': 0.0007334142499289829,
#  'LH rain LS sun': 0.0007334142499289829,
#  'LH rain MV clouds': 0.007720149999252454,
#  'LH rain MV fog': 0.007720149999252454,
#  'LH rain MV rain': 0.007720149999252454,
#  'LH rain MV snow': 0.007720149999252454,
#  'LH rain MV sun': 0.007720149999252454,
#  'LH rain NH clouds': 0.0012738247498766547,
#  'LH rain NH fog': 0.0012738247498766547,
#  'LH rain NH rain': 0.0012738247498766547,
#  'LH rain NH snow': 0.0012738247498766547,
#  'LH rain NH sun': 0.0012738247498766547,
#  'LH rain PG clouds': 0.0026634517497420964,
#  'LH rain PG fog': 0.0026634517497420964,
#  'LH rain PG rain': 0.0026634517497420964,
#  'LH rain PG snow': 0.0026634517497420964,
#  'LH rain PG sun': 0.0026634517497420964,
#  'LH rain RG clouds': 0.00030880599997009815,
#  'LH rain RG fog': 0.00030880599997009815,
#  'LH rain RG rain': 0.00030880599997009815,
#  'LH rain RG snow': 0.00030880599997009815,
#  'LH rain RG sun': 0.00030880599997009815,
#  'LH rain RK clouds': 3.860074999626227e-05,
#  'LH rain RK fog': 3.860074999626227e-05,
#  'LH rain RK rain': 3.860074999626227e-05,
#  'LH rain RK snow': 3.860074999626227e-05,
#  'LH rain RK sun': 3.860074999626227e-05,
#  'LH rain SP clouds': 0.001042220249899081,
#  'LH rain SP fog': 0.001042220249899081,
#  'LH rain SP rain': 0.001042220249899081,
#  'LH rain SP snow': 0.001042220249899081,
#  'LH rain SP sun': 0.001042220249899081,
#  'LH rain SV clouds': 0.0074885454992748785,
#  'LH rain SV fog': 0.0074885454992748785,
#  'LH rain SV rain': 0.0074885454992748785,
#  'LH rain SV snow': 0.0074885454992748785,
#  'LH rain SV sun': 0.0074885454992748785,
#  'LH rain VB clouds': 0.008916773249136582,
#  'LH rain VB fog': 0.008916773249136582,
#  'LH rain VB rain': 0.008916773249136582,
#  'LH rain VB snow': 0.008916773249136582,
#  'LH rain VB sun': 0.008916773249136582,
#  'LH snow LH rain': 0.011425821998893632,
#  'LH snow VB rain': 0.008916773249136582,
#  'LH sun LH rain': 0.011425821998893632,
#  'LH sun VB rain': 0.008916773249136582,
#  'LN clouds LH rain': 0.0010057941900434536,
#  'LN clouds VB rain': 0.0007849272226352627,
#  'LN fog LH rain': 0.0010057941900434536,
#  'LN fog VB rain': 0.0007849272226352627,
#  'LN rain LH rain': 0.0010057941900434536,
#  'LN rain VB rain': 0.0007849272226352627,
#  'LN snow LH rain': 0.0010057941900434536,
#  'LN snow VB rain': 0.0007849272226352627,
#  'LN sun LH rain': 0.0010057941900434536,
#  'LN sun VB rain': 0.0007849272226352627,
#  'LS clouds LH rain': 0.0007644035844330245,
#  'LS clouds VB rain': 0.0005965446892027997,
#  'LS fog LH rain': 0.0007644035844330245,
#  'LS fog VB rain': 0.0005965446892027997,
#  'LS rain LH rain': 0.0007644035844330245,
#  'LS rain VB rain': 0.0005965446892027997,
#  'LS snow LH rain': 0.0007644035844330245,
#  'LS snow VB rain': 0.0005965446892027997,
#  'LS sun LH rain': 0.0007644035844330245,
#  'LS sun VB rain': 0.0005965446892027997,
#  'MV clouds LH rain': 0.007442877006321557,
#  'MV clouds VB rain': 0.005808461447500943,
#  'MV fog LH rain': 0.007442877006321557,
#  'MV fog VB rain': 0.005808461447500943,
#  'MV rain LH rain': 0.007442877006321557,
#  'MV rain VB rain': 0.005808461447500943,
#  'MV snow LH rain': 0.007442877006321557,
#  'MV snow VB rain': 0.005808461447500943,
#  'MV sun LH rain': 0.007442877006321557,
#  'MV sun VB rain': 0.005808461447500943,
#  'NH clouds LH rain': 0.0012471847956538821,
#  'NH clouds VB rain': 0.0009733097560677257,
#  'NH fog LH rain': 0.0012471847956538821,
#  'NH fog VB rain': 0.0009733097560677257,
#  'NH rain LH rain': 0.0012471847956538821,
#  'NH rain VB rain': 0.0009733097560677257,
#  'NH snow LH rain': 0.0012471847956538821,
#  'NH snow VB rain': 0.0009733097560677257,
#  'NH sun LH rain': 0.0012471847956538821,
#  'NH sun VB rain': 0.0009733097560677257,
#  'PG clouds LH rain': 0.002615064894112979,
#  'PG clouds VB rain': 0.002040810778851683,
#  'PG fog LH rain': 0.002615064894112979,
#  'PG fog VB rain': 0.002040810778851683,
#  'PG rain LH rain': 0.002615064894112979,
#  'PG rain VB rain': 0.002040810778851683,
#  'PG snow LH rain': 0.002615064894112979,
#  'PG snow VB rain': 0.002040810778851683,
#  'PG sun LH rain': 0.002615064894112979,
#  'PG sun VB rain': 0.002040810778851683,
#  'RG clouds LH rain': 0.0003218541408139052,
#  'RG clouds VB rain': 0.00025117671124328403,
#  'RG fog LH rain': 0.0003218541408139052,
#  'RG fog VB rain': 0.00025117671124328403,
#  'RG rain LH rain': 0.0003218541408139052,
#  'RG rain VB rain': 0.00025117671124328403,
#  'RG snow LH rain': 0.0003218541408139052,
#  'RG snow VB rain': 0.00025117671124328403,
#  'RG sun LH rain': 0.0003218541408139052,
#  'RG sun VB rain': 0.00025117671124328403,
#  'RK clouds LH rain': 4.023176760173815e-05,
#  'RK clouds VB rain': 3.1397088905410504e-05,
#  'RK fog LH rain': 4.023176760173815e-05,
#  'RK fog VB rain': 3.1397088905410504e-05,
#  'RK rain LH rain': 4.023176760173815e-05,
#  'RK rain VB rain': 3.1397088905410504e-05,
#  'RK snow LH rain': 4.023176760173815e-05,
#  'RK snow VB rain': 3.1397088905410504e-05,
#  'RK sun LH rain': 4.023176760173815e-05,
#  'RK sun VB rain': 3.1397088905410504e-05,
#  'SP clouds LH rain': 0.0010862577252469298,
#  'SP clouds VB rain': 0.0008477214004460838,
#  'SP fog LH rain': 0.0010862577252469298,
#  'SP fog VB rain': 0.0008477214004460838,
#  'SP rain LH rain': 0.0010862577252469298,
#  'SP rain VB rain': 0.0008477214004460838,
#  'SP snow LH rain': 0.0010862577252469298,
#  'SP snow VB rain': 0.0008477214004460838,
#  'SP sun LH rain': 0.0010862577252469298,
#  'SP sun VB rain': 0.0008477214004460838,
#  'SV clouds LH rain': 0.006799168724693746,
#  'SV clouds VB rain': 0.0053061080250143755,
#  'SV fog LH rain': 0.006799168724693746,
#  'SV fog VB rain': 0.0053061080250143755,
#  'SV rain LH rain': 0.006799168724693746,
#  'SV rain VB rain': 0.0053061080250143755,
#  'SV snow LH rain': 0.006799168724693746,
#  'SV snow VB rain': 0.0053061080250143755,
#  'SV sun LH rain': 0.006799168724693746,
#  'SV sun VB rain': 0.0053061080250143755,
#  'VB clouds LH rain': 0.008891220639984128,
#  'VB clouds VB rain': 0.006938756648095723,
#  'VB fog LH rain': 0.008891220639984128,
#  'VB fog VB rain': 0.006938756648095723,
#  'VB rain AA clouds': 0.0012615921178355859,
#  'VB rain AA fog': 0.0012615921178355859,
#  'VB rain AA rain': 0.0012615921178355859,
#  'VB rain AA snow': 0.0012615921178355859,
#  'VB rain AA sun': 0.0012615921178355859,
#  'VB rain AG clouds': 0.0001201516302700558,
#  'VB rain AG fog': 0.0001201516302700558,
#  'VB rain AG rain': 0.0001201516302700558,
#  'VB rain AG snow': 0.0001201516302700558,
#  'VB rain AG sun': 0.0001201516302700558,
#  'VB rain CL clouds': 0.0060075815135027895,
#  'VB rain CL fog': 0.0060075815135027895,
#  'VB rain CL rain': 0.0060075815135027895,
#  'VB rain CL snow': 0.0060075815135027895,
#  'VB rain CL sun': 0.0060075815135027895,
#  'VB rain CS clouds': 0.001742198638915809,
#  'VB rain CS fog': 0.001742198638915809,
#  'VB rain CS rain': 0.001742198638915809,
#  'VB rain CS snow': 0.001742198638915809,
#  'VB rain CS sun': 0.001742198638915809,
#  'VB rain DK clouds': 0.0009912509497279603,
#  'VB rain DK fog': 0.0009912509497279603,
#  'VB rain DK rain': 0.0009912509497279603,
#  'VB rain DK snow': 0.0009912509497279603,
#  'VB rain DK sun': 0.0009912509497279603,
#  'VB rain DR clouds': 0.0010212888572954744,
#  'VB rain DR fog': 0.0010212888572954744,
#  'VB rain DR rain': 0.0010212888572954744,
#  'VB rain DR snow': 0.0010212888572954744,
#  'VB rain DR sun': 0.0010212888572954744,
#  'VB rain GR clouds': 0.0,
#  'VB rain GR fog': 0.0,
#  'VB rain GR rain': 0.0,
#  'VB rain GR snow': 0.0,
#  'VB rain GR sun': 0.0,
#  'VB rain KM clouds': 0.000540682336215251,
#  'VB rain KM fog': 0.000540682336215251,
#  'VB rain KM rain': 0.000540682336215251,
#  'VB rain KM snow': 0.000540682336215251,
#  'VB rain KM sun': 0.000540682336215251,
#  'VB rain KR clouds': 0.0009311751345929325,
#  'VB rain KR fog': 0.0009311751345929325,
#  'VB rain KR rain': 0.0009311751345929325,
#  'VB rain KR snow': 0.0009311751345929325,
#  'VB rain KR sun': 0.0009311751345929325,
#  'VB rain LH clouds': 0.008891220639984128,
#  'VB rain LH fog': 0.008891220639984128,
#  'VB rain LH rain': 0.008891220639984128,
#  'VB rain LH snow': 0.008891220639984128,
#  'VB rain LH sun': 0.008891220639984128,
#  'VB rain LN clouds': 0.0009311751345929325,
#  'VB rain LN fog': 0.0009311751345929325,
#  'VB rain LN rain': 0.0009311751345929325,
#  'VB rain LN snow': 0.0009311751345929325,
#  'VB rain LN sun': 0.0009311751345929325,
#  'VB rain LS clouds': 0.0005707202437827651,
#  'VB rain LS fog': 0.0005707202437827651,
#  'VB rain LS rain': 0.0005707202437827651,
#  'VB rain LS snow': 0.0005707202437827651,
#  'VB rain LS sun': 0.0005707202437827651,
#  'VB rain MV clouds': 0.0060075815135027895,
#  'VB rain MV fog': 0.0060075815135027895,
#  'VB rain MV rain': 0.0060075815135027895,
#  'VB rain MV snow': 0.0060075815135027895,
#  'VB rain MV sun': 0.0060075815135027895,
#  'VB rain NH clouds': 0.0009912509497279603,
#  'VB rain NH fog': 0.0009912509497279603,
#  'VB rain NH rain': 0.0009912509497279603,
#  'VB rain NH snow': 0.0009912509497279603,
#  'VB rain NH sun': 0.0009912509497279603,
#  'VB rain PG clouds': 0.002072615622158463,
#  'VB rain PG fog': 0.002072615622158463,
#  'VB rain PG rain': 0.002072615622158463,
#  'VB rain PG snow': 0.002072615622158463,
#  'VB rain PG sun': 0.002072615622158463,
#  'VB rain RG clouds': 0.0002403032605401116,
#  'VB rain RG fog': 0.0002403032605401116,
#  'VB rain RG rain': 0.0002403032605401116,
#  'VB rain RG snow': 0.0002403032605401116,
#  'VB rain RG sun': 0.0002403032605401116,
#  'VB rain RK clouds': 3.003790756751395e-05,
#  'VB rain RK fog': 3.003790756751395e-05,
#  'VB rain RK rain': 3.003790756751395e-05,
#  'VB rain RK snow': 3.003790756751395e-05,
#  'VB rain RK sun': 3.003790756751395e-05,
#  'VB rain SP clouds': 0.0008110235043228766,
#  'VB rain SP fog': 0.0008110235043228766,
#  'VB rain SP rain': 0.0008110235043228766,
#  'VB rain SP snow': 0.0008110235043228766,
#  'VB rain SP sun': 0.0008110235043228766,
#  'VB rain SV clouds': 0.005827354068097706,
#  'VB rain SV fog': 0.005827354068097706,
#  'VB rain SV rain': 0.005827354068097706,
#  'VB rain SV snow': 0.005827354068097706,
#  'VB rain SV sun': 0.005827354068097706,
#  'VB rain VB clouds': 0.006938756648095723,
#  'VB rain VB fog': 0.006938756648095723,
#  'VB rain VB rain': 0.006938756648095723,
#  'VB rain VB snow': 0.006938756648095723,
#  'VB rain VB sun': 0.006938756648095723,
#  'VB snow LH rain': 0.008891220639984128,
#  'VB snow VB rain': 0.006938756648095723,
#  'VB sun LH rain': 0.008891220639984128,
#  'VB sun VB rain': 0.006938756648095723}

# %%
# predicate defining that mercedes wins both races taking weather conditions into consideration
def BothMercedesWeather(outcome): 
    return (('LH' in outcome and 'VB' in outcome) or (outcome.count('LH')==2) or (outcome.count('VB')==2))
such_that(BothMercedesWeather,SRWC)
# Out:
# {'LH clouds LH clouds': 0.012634790613786237,
#  'LH clouds LH fog': 0.012634790613786237,
#  'LH clouds LH rain': 0.012634790613786237,
#  'LH clouds LH snow': 0.012634790613786237,
#  'LH clouds LH sun': 0.012634790613786237,
#  'LH clouds VB clouds': 0.009860258891164257,
#  'LH clouds VB fog': 0.009860258891164257,
#  'LH clouds VB rain': 0.009860258891164257,
#  'LH clouds VB snow': 0.009860258891164257,
#  'LH clouds VB sun': 0.009860258891164257,
#  'LH fog LH clouds': 0.012634790613786237,
#  'LH fog LH fog': 0.012634790613786237,
#  'LH fog LH rain': 0.012634790613786237,
#  'LH fog LH snow': 0.012634790613786237,
#  'LH fog LH sun': 0.012634790613786237,
#  'LH fog VB clouds': 0.009860258891164257,
#  'LH fog VB fog': 0.009860258891164257,
#  'LH fog VB rain': 0.009860258891164257,
#  'LH fog VB snow': 0.009860258891164257,
#  'LH fog VB sun': 0.009860258891164257,
#  'LH rain LH clouds': 0.012634790613786237,
#  'LH rain LH fog': 0.012634790613786237,
#  'LH rain LH rain': 0.012634790613786237,
#  'LH rain LH snow': 0.012634790613786237,
#  'LH rain LH sun': 0.012634790613786237,
#  'LH rain VB clouds': 0.009860258891164257,
#  'LH rain VB fog': 0.009860258891164257,
#  'LH rain VB rain': 0.009860258891164257,
#  'LH rain VB snow': 0.009860258891164257,
#  'LH rain VB sun': 0.009860258891164257,
#  'LH snow LH clouds': 0.012634790613786237,
#  'LH snow LH fog': 0.012634790613786237,
#  'LH snow LH rain': 0.012634790613786237,
#  'LH snow LH snow': 0.012634790613786237,
#  'LH snow LH sun': 0.012634790613786237,
#  'LH snow VB clouds': 0.009860258891164257,
#  'LH snow VB fog': 0.009860258891164257,
#  'LH snow VB rain': 0.009860258891164257,
#  'LH snow VB snow': 0.009860258891164257,
#  'LH snow VB sun': 0.009860258891164257,
#  'LH sun LH clouds': 0.012634790613786237,
#  'LH sun LH fog': 0.012634790613786237,
#  'LH sun LH rain': 0.012634790613786237,
#  'LH sun LH snow': 0.012634790613786237,
#  'LH sun LH sun': 0.012634790613786237,
#  'LH sun VB clouds': 0.009860258891164257,
#  'LH sun VB fog': 0.009860258891164257,
#  'LH sun VB rain': 0.009860258891164257,
#  'LH sun VB snow': 0.009860258891164257,
#  'LH sun VB sun': 0.009860258891164257,
#  'VB clouds LH clouds': 0.009832002555094218,
#  'VB clouds LH fog': 0.009832002555094218,
#  'VB clouds LH rain': 0.009832002555094218,
#  'VB clouds LH snow': 0.009832002555094218,
#  'VB clouds LH sun': 0.009832002555094218,
#  'VB clouds VB clouds': 0.007672947939955286,
#  'VB clouds VB fog': 0.007672947939955286,
#  'VB clouds VB rain': 0.007672947939955286,
#  'VB clouds VB snow': 0.007672947939955286,
#  'VB clouds VB sun': 0.007672947939955286,
#  'VB fog LH clouds': 0.009832002555094218,
#  'VB fog LH fog': 0.009832002555094218,
#  'VB fog LH rain': 0.009832002555094218,
#  'VB fog LH snow': 0.009832002555094218,
#  'VB fog LH sun': 0.009832002555094218,
#  'VB fog VB clouds': 0.007672947939955286,
#  'VB fog VB fog': 0.007672947939955286,
#  'VB fog VB rain': 0.007672947939955286,
#  'VB fog VB snow': 0.007672947939955286,
#  'VB fog VB sun': 0.007672947939955286,
#  'VB rain LH clouds': 0.009832002555094218,
#  'VB rain LH fog': 0.009832002555094218,
#  'VB rain LH rain': 0.009832002555094218,
#  'VB rain LH snow': 0.009832002555094218,
#  'VB rain LH sun': 0.009832002555094218,
#  'VB rain VB clouds': 0.007672947939955286,
#  'VB rain VB fog': 0.007672947939955286,
#  'VB rain VB rain': 0.007672947939955286,
#  'VB rain VB snow': 0.007672947939955286,
#  'VB rain VB sun': 0.007672947939955286,
#  'VB snow LH clouds': 0.009832002555094218,
#  'VB snow LH fog': 0.009832002555094218,
#  'VB snow LH rain': 0.009832002555094218,
#  'VB snow LH snow': 0.009832002555094218,
#  'VB snow LH sun': 0.009832002555094218,
#  'VB snow VB clouds': 0.007672947939955286,
#  'VB snow VB fog': 0.007672947939955286,
#  'VB snow VB rain': 0.007672947939955286,
#  'VB snow VB snow': 0.007672947939955286,
#  'VB snow VB sun': 0.007672947939955286,
#  'VB sun LH clouds': 0.009832002555094218,
#  'VB sun LH fog': 0.009832002555094218,
#  'VB sun LH rain': 0.009832002555094218,
#  'VB sun LH snow': 0.009832002555094218,
#  'VB sun LH sun': 0.009832002555094218,
#  'VB sun VB clouds': 0.007672947939955286,
#  'VB sun VB fog': 0.007672947939955286,
#  'VB sun VB rain': 0.007672947939955286,
#  'VB sun VB snow': 0.007672947939955286,
#  'VB sun VB sun': 0.007672947939955286}

# %% [markdown]
# ## Probability of mercedes winning both races given that mercedes has won one of the races on a rainy day.

# %%
# probability of mercedes winning both races given that mercedes has won one of the races on a rainy day
p(BothMercedesWeather,such_that(MercedesRain,SRWC))
# Out:
# 0.32555315282499075
